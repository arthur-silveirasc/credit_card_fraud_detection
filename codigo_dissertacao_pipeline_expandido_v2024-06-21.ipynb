# %% [markdown]
# # Início

# %% [markdown]
# https://www.kaggle.com/competitions/ieee-fraud-detection

# %% [markdown]
# https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud

# %% [markdown]
# Este notebook engloba os seguinte passos:
#
# * Feature Engineering
#     * Tratando Colunas com Valores Faltantes (deletar colunas com 75% de valores faltantes)
#     * Tratando Colunas com valores únicos (deletar)
#     * Tratando Linhas com Valores Faltantes (deletar linhas com 75% de valores faltantes)
#     * Substituindo NaNs remanescentes por média e moda
#     * Codificação de variáveis categóricas
# * Separação entre base de treino e de teste, a partir da base de treino
# * Balanceamento de classes
#     * Undersample
#         * Resample
#         * Random UnderSampling (RUS)
#         * Near Miss
#         * Instance Hardness Threshold
#     * Oversample
#         * Resample
#         * Random OverSampling (ROS)
#         * SMOTE
#         * Borderline SMOTE
#         * AdaSyn
# * Treinamento dos algoritmos e análise de desempenho
#     * Algoritmos utilizados
#         * Extra Trees
#         * Decision Tree
#     * Métricas de desempenho por threshold (0,05 a 0,50) e por técnica de balanceamento
#         * F1-score positivo (iteração por iteração)
#         * Wall time

# %% [markdown]
# # Importando Bibliotecas

# %%
# inicializando cronômetro
import time
t0 = time.time()

# %%
# !pip install lightgbm
# !pip install xgboost
# !pip install catboost

# !pip install scikit-learn==1.2.2
# !pip install numpy==1.24.0
# !pip install pandas==2.0.2
# !pip install imbalanced-learn==0.10.1
#!pip install scikit-learn==1.1.1
#!pip install numpy==1.22.4
#!pip install pandas==1.2.4
#!pip install imbalanced-learn==0.10.1
# Out:
# Requirement already satisfied: lightgbm in c:\users\arthu\anaconda3\lib\site-packages (3.3.5)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\arthu\anaconda3\lib\site-packages (from lightgbm) (1.2.2)
# Requirement already satisfied: numpy in c:\users\arthu\anaconda3\lib\site-packages (from lightgbm) (1.24.0)
# Requirement already satisfied: wheel in c:\users\arthu\anaconda3\lib\site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: scipy in c:\users\arthu\anaconda3\lib\site-packages (from lightgbm) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: xgboost in c:\users\arthu\anaconda3\lib\site-packages (1.7.5)
# Requirement already satisfied: scipy in c:\users\arthu\anaconda3\lib\site-packages (from xgboost) (1.11.1)
# Requirement already satisfied: numpy in c:\users\arthu\anaconda3\lib\site-packages (from xgboost) (1.24.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: catboost in c:\users\arthu\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: plotly in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (5.15.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (2.0.2)
# Requirement already satisfied: scipy in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (1.11.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (1.24.0)
# Requirement already satisfied: graphviz in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (3.7.1)
# Requirement already satisfied: six in c:\users\arthu\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arthu\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arthu\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arthu\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2022.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arthu\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\arthu\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: scikit-learn==1.2.2 in c:\users\arthu\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (1.24.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arthu\anaconda3\lib\site-packages (from scikit-learn==1.2.2) (3.1.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: numpy==1.24.0 in c:\users\arthu\anaconda3\lib\site-packages (1.24.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: pandas==2.0.2 in c:\users\arthu\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arthu\anaconda3\lib\site-packages (from pandas==2.0.2) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\arthu\anaconda3\lib\site-packages (from pandas==2.0.2) (1.24.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arthu\anaconda3\lib\site-packages (from pandas==2.0.2) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arthu\anaconda3\lib\site-packages (from pandas==2.0.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\arthu\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.0.2) (1.16.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: imbalanced-learn==0.10.1 in c:\users\arthu\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\arthu\anaconda3\lib\site-packages (from imbalanced-learn==0.10.1) (1.24.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\arthu\anaconda3\lib\site-packages (from imbalanced-learn==0.10.1) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\arthu\anaconda3\lib\site-packages (from imbalanced-learn==0.10.1) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\arthu\anaconda3\lib\site-packages (from imbalanced-learn==0.10.1) (1.11.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arthu\anaconda3\lib\site-packages (from imbalanced-learn==0.10.1) (3.1.0)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, log_loss, roc_auc_score, accuracy_score
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
from sklearn.metrics import confusion_matrix
from scipy import stats
pd.options.display.max_rows = 999
pd.options.display.precision = 15

import datetime
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, \
KFold, RepeatedKFold, GroupKFold, GridSearchCV, train_test_split, TimeSeriesSplit
from sklearn import metrics
from sklearn import linear_model
import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.style.use("ggplot")
color_pal = [x['color'] for x in plt.rcParams['axes.prop_cycle']]

# %%
# checar utilização de memória
# !pip install GPUtil

from GPUtil import showUtilization as gpu_usage
gpu_usage()
# Out:
# Requirement already satisfied: GPUtil in c:\users\arthu\anaconda3\lib\site-packages (1.4.0)
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  7% |
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)

# %%
#limpando cache do CUDA para melhor desempenho do paralelismo
# !pip install torch
import torch
torch.cuda.empty_cache()
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\arthu\anaconda3\lib\site-packages)
# Requirement already satisfied: torch in c:\users\arthu\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: typing_extensions in c:\users\arthu\anaconda3\lib\site-packages (from torch) (4.4.0)

# %% [markdown]
# # Importando Dados

# %%
folder_path = 'C:/Users/arthu/Desktop/codigo_dissertacao/input/'
train_identity = pd.read_csv(f'{folder_path}train_identity.csv')
train_transaction = pd.read_csv(f'{folder_path}train_transaction.csv')
test_identity = pd.read_csv(f'{folder_path}test_identity.csv')
test_transaction = pd.read_csv(f'{folder_path}test_transaction.csv')
sub = pd.read_csv(f'{folder_path}sample_submission.csv')

# combinando dados de transações e de identidade associada às transações (p.ex., IP e browser utilizado)
train = pd.merge(train_transaction, train_identity, on = 'TransactionID', how = 'left')
test = pd.merge(test_transaction, test_identity, on = 'TransactionID', how = 'left')

# %%
creditcard = pd.read_csv(f'{folder_path}creditcard.csv')

# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# ## Estatística Básica

# %%
# função resumetable traz as estatísticas básicas do conjunto de dados
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = \
        round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
resumetable(creditcard)
# Out:
# Dataset Shape: (284807, 31)
#       Name   dtypes  Missing  Uniques          First Value       Second Value  \
# 0     Time  float64        0   124592    0.000000000000000  0.000000000000000
# 1       V1  float64        0   275663   -1.359807133673800  1.191857111314860
# 2       V2  float64        0   275663   -0.072781173309850  0.266150712059630
# 3       V3  float64        0   275663    2.536346737969140  0.166480113353210
# 4       V4  float64        0   275663    1.378155224274430  0.448154078460911
# 5       V5  float64        0   275663   -0.338320769942518  0.060017649282224
# 6       V6  float64        0   275663    0.462387777762292 -0.082360808815569
# 7       V7  float64        0   275663    0.239598554061257 -0.078802983332311
# 8       V8  float64        0   275663    0.098697901261051  0.085101654914810
# 9       V9  float64        0   275663    0.363786969611213 -0.255425128109186
# 10     V10  float64        0   275663    0.090794171978932 -0.166974414004614
# 11     V11  float64        0   275663   -0.551599533260813  1.612726661054790
# 12     V12  float64        0   275663   -0.617800855762348  1.065235311372870
# 13     V13  float64        0   275663   -0.991389847235408  0.489095015896080
# 14     V14  float64        0   275663   -0.311169353699879 -0.143772296441519
# 15     V15  float64        0   275663    1.468176972094270  0.635558093258208
# 16     V16  float64        0   275663   -0.470400525259478  0.463917041022171
# 17     V17  float64        0   275663    0.207971241929242 -0.114804663102346
# 18     V18  float64        0   275663    0.025790580198559 -0.183361270123994
# 19     V19  float64        0   275663    0.403992960255733 -0.145783041325259
# 20     V20  float64        0   275663    0.251412098239705 -0.069083135223020
# 21     V21  float64        0   275663   -0.018306777944153 -0.225775248033138
# 22     V22  float64        0   275663    0.277837575558899 -0.638671952771851
# 23     V23  float64        0   275663   -0.110473910188767  0.101288021253234
# 24     V24  float64        0   275663    0.066928074914673 -0.339846475529127
# 25     V25  float64        0   275663    0.128539358273528  0.167170404418143
# 26     V26  float64        0   275663   -0.189114843888824  0.125894532368176
# 27     V27  float64        0   275663    0.133558376740387 -0.008983099143228
# 28     V28  float64        0   275663   -0.021053053453821  0.014724169192493
# 29  Amount  float64        0    32767  149.620000000000005  2.690000000000000
# 30   Class    int64        0        2    0.000000000000000  0.000000000000000
#
#             Third Value             Entropy
# 0     1.000000000000000  16.690000000000001
# 1    -1.358354061598230  18.030000000000001
# 2    -1.340163074736090  18.030000000000001
# 3     1.773209342631190  18.030000000000001
# 4     0.379779593034328  18.030000000000001
# 5    -0.503198133318193  18.030000000000001
# 6     1.800499380792630  18.030000000000001
# 7     0.791460956450422  18.030000000000001
# 8     0.247675786588991  18.030000000000001
# 9    -1.514654322605830  18.030000000000001
# 10    0.207642865216696  18.030000000000001
# 11    0.624501459424895  18.030000000000001
# 12    0.066083685268831  18.030000000000001
# 13    0.717292731410831  18.030000000000001
# 14   -0.165945922763554  18.030000000000001
# 15    2.345864949015810  18.030000000000001
# 16   -2.890083194442310  18.030000000000001
# 17    1.109969378695990  18.030000000000001
# 18   -0.121359313195888  18.030000000000001
# 19   -2.261857095304140  18.030000000000001
# 20    0.524979725224404  18.030000000000001
# 21    0.247998153469754  18.030000000000001
# 22    0.771679401917229  18.030000000000001
# 23    0.909412262347719  18.030000000000001
# 24   -0.689280956490685  18.030000000000001
# 25   -0.327641833735251  18.030000000000001
# 26   -0.139096571514147  18.030000000000001
# 27   -0.055352794038426  18.030000000000001
# 28   -0.059751840592920  18.030000000000001
# 29  378.660000000000025  11.500000000000000
# 30    0.000000000000000   0.020000000000000

# %%
resumetable(train)[:25]
# Out:
# Dataset Shape: (590540, 434)
#               Name   dtypes  Missing  Uniques First Value Second Value  \
# 0    TransactionID    int64        0   590540     2987000      2987001
# 1          isFraud    int64        0        2           0            0
# 2    TransactionDT    int64        0   573349       86400        86401
# 3   TransactionAmt  float64        0    20902        68.5         29.0
# 4        ProductCD   object        0        5           W            W
# 5            card1    int64        0    13553       13926         2755
# 6            card2  float64     8933      500         NaN        404.0
# 7            card3  float64     1565      114       150.0        150.0
# 8            card4   object     1577        4    discover   mastercard
# 9            card5  float64     4259      119       142.0        102.0
# 10           card6   object     1571        4      credit       credit
# 11           addr1  float64    65706      332       315.0        325.0
# 12           addr2  float64    65706       74        87.0         87.0
# 13           dist1  float64   352271     2651        19.0          NaN
# 14           dist2  float64   552913     1751         NaN          NaN
# 15   P_emaildomain   object    94456       59         NaN    gmail.com
# 16   R_emaildomain   object   453249       60         NaN          NaN
# 17              C1  float64        0     1657         1.0          1.0
# 18              C2  float64        0     1216         1.0          1.0
# 19              C3  float64        0       27         0.0          0.0
# 20              C4  float64        0     1260         0.0          0.0
# 21              C5  float64        0      319         0.0          0.0
# 22              C6  float64        0     1328         1.0          1.0
# 23              C7  float64        0     1103         0.0          0.0
# 24              C8  float64        0     1253         0.0          0.0
#
#     Third Value             Entropy
# 0       2987002  19.170000000000002
# 1             0   0.220000000000000
# 2         86469  19.109999999999999
# 3          59.0   8.350000000000000
# 4             W   1.280000000000000
# 5          4663   9.970000000000001
# 6         490.0   6.320000000000000
# 7         150.0   0.680000000000000
# 8          visa   1.090000000000000
# 9         166.0   2.660000000000000
# 10        debit   0.820000000000000
# 11        330.0   5.060000000000000
# 12         87.0   0.080000000000000
# 13        287.0   6.340000000000000
# 14          NaN   7.420000000000000
# 15  outlook.com   2.680000000000000
# 16          NaN   2.760000000000000
# 17          1.0   2.720000000000000
# 18          1.0   2.750000000000000
# 19          0.0   0.040000000000000
# 20          0.0   1.120000000000000
# 21          0.0   2.060000000000000
# 22          1.0   2.520000000000000
# 23          0.0   0.710000000000000
# 24          0.0   1.250000000000000

# %%
resumetable(test)[:25]
# Out:
# Dataset Shape: (506691, 433)
#               Name   dtypes  Missing  Uniques         First Value  \
# 0    TransactionID    int64        0   506691             3663549
# 1    TransactionDT    int64        0   494686            18403224
# 2   TransactionAmt  float64        0    14119  31.949999999999999
# 3        ProductCD   object        0        5                   W
# 4            card1    int64        0    13244               10409
# 5            card2  float64     8654      497               111.0
# 6            card3  float64     3002      115               150.0
# 7            card4   object     3086        4                visa
# 8            card5  float64     4547      102               226.0
# 9            card6   object     3007        3               debit
# 10           addr1  float64    65609      292               170.0
# 11           addr2  float64    65609       72                87.0
# 12           dist1  float64   291217     1988                 1.0
# 13           dist2  float64   470255     1814                 NaN
# 14   P_emaildomain   object    69192       60           gmail.com
# 15   R_emaildomain   object   370821       60                 NaN
# 16              C1  float64        3     1174                 6.0
# 17              C2  float64        3     1123                 6.0
# 18              C3  float64        3       31                 0.0
# 19              C4  float64        3      728                 0.0
# 20              C5  float64        3      353                 3.0
# 21              C6  float64        3      834                 4.0
# 22              C7  float64        3      518                 0.0
# 23              C8  float64        3      442                 0.0
# 24              C9  float64        3      354                 6.0
#
#    Second Value  Third Value             Entropy
# 0       3663550      3663551  18.949999999999999
# 1      18403263     18403310  18.899999999999999
# 2          49.0        171.0   8.080000000000000
# 3             W            W   1.370000000000000
# 4          4272         4476   9.949999999999999
# 5         111.0        574.0   6.280000000000000
# 6         150.0        150.0   0.810000000000000
# 7          visa         visa   1.050000000000000
# 8         226.0        226.0   2.630000000000000
# 9         debit        debit   0.790000000000000
# 10        299.0        472.0   5.100000000000000
# 11         87.0         87.0   0.110000000000000
# 12          4.0       2635.0   5.990000000000000
# 13          NaN          NaN   7.900000000000000
# 14      aol.com  hotmail.com   2.670000000000000
# 15          NaN          NaN   2.690000000000000
# 16          3.0          2.0   2.680000000000000
# 17          2.0          2.0   2.760000000000000
# 18          0.0          0.0   0.180000000000000
# 19          0.0          0.0   1.210000000000000
# 20          0.0          0.0   1.930000000000000
# 21          1.0          5.0   2.470000000000000
# 22          0.0          0.0   0.820000000000000
# 23          0.0          0.0   1.360000000000000
# 24          2.0          4.0   2.610000000000000

# %%
# checando o desbalanceamento dos dados por quantidade de transações e valor das transações
# ("TransactionAmt")
train['TransactionAmt'] = train['TransactionAmt'].astype(float)
total = len(train)
total_amt = train.groupby(['isFraud'])['TransactionAmt'].sum().sum()
plt.figure(figsize = (16, 6))

plt.subplot(121)
g = sns.countplot(x = 'isFraud', data = train, )
g.set_title("Fraud Transactions Distribution \n# 0: No Fraud | 1: Fraud #", fontsize = 22)
g.set_xlabel("Is Fraud?", fontsize = 18)
g.set_ylabel('Count', fontsize = 18)

for p in g.patches:
    height = p.get_height()
    g.text(p.get_x() + p.get_width()/2.,
          height + 3,
          '{:1.2f}%'.format(height/total * 100),
          ha = "center", fontsize = 15)

perc_amt = (train.groupby(['isFraud'])['TransactionAmt'].sum())
perc_amt = perc_amt.reset_index()
plt.subplot(122)
g1 = sns.barplot(x = 'isFraud', y = 'TransactionAmt', dodge = True, data = perc_amt)
g1.set_title("% Total Amount in Transaction Amt \n# 0: No Fraud | 1: Fraud #", fontsize = 22)
g1.set_xlabel("Is Fraud?", fontsize = 18)
g1.set_ylabel('Total Transaction Amount Scalar', fontsize = 18)
for p in g1.patches:
    height = p.get_height()
    g1.text(p.get_x() + p.get_width()/2.,
           height + 3,
           '{:1.2f}%'.format(height/total_amt * 100),
           ha = "center", fontsize = 15)

# %%
# checando o desbalanceamento dos dados por quantidade de transações e valor das transações
# ("TransactionAmt")
creditcard['Amount'] = creditcard['Amount'].astype(float)
total = len(creditcard)
total_amt = creditcard.groupby(['Class'])['Amount'].sum().sum()
plt.figure(figsize = (16, 6))

plt.subplot(121)
g = sns.countplot(x = 'Class', data = creditcard, )
g.set_title("Fraud Transactions Distribution \n# 0: No Fraud | 1: Fraud #", fontsize = 22)
g.set_xlabel("Is Fraud?", fontsize = 18)
g.set_ylabel('Count', fontsize = 18)

for p in g.patches:
    height = p.get_height()
    g.text(p.get_x() + p.get_width()/2.,
          height + 3,
          '{:1.2f}%'.format(height/total * 100),
          ha = "center", fontsize = 15)

perc_amt = (creditcard.groupby(['Class'])['Amount'].sum())
perc_amt = perc_amt.reset_index()
plt.subplot(122)
g1 = sns.barplot(x = 'Class', y = 'Amount', dodge = True, data = perc_amt)
g1.set_title("% Total Amount in Transaction Amt \n# 0: No Fraud | 1: Fraud #", fontsize = 22)
g1.set_xlabel("Is Fraud?", fontsize = 18)
g1.set_ylabel('Total Transaction Amount Scalar', fontsize = 18)
for p in g1.patches:
    height = p.get_height()
    g1.text(p.get_x() + p.get_width()/2.,
           height + 3,
           '{:1.2f}%'.format(height/total_amt * 100),
           ha = "center", fontsize = 15)

# %% [markdown]
# # Feature Engineering (Dataset 01)

# %% [markdown]
# ## Convertendo "TransactionDT" em data, dias, horários e dias da semana

# %%
# a primeira data é 01/12/2017 e será usada o timedelta para calcular os atributos de 
# datas e horários

import datetime

START_DATE = '2017-12-01'
start_date = datetime.datetime.strptime(START_DATE, "%Y-%m-%d")
train["Date"] = train['TransactionDT'].apply(lambda x: (start_date + datetime.timedelta
                                                             (seconds = x)))

train['_Weekdays'] = train['Date'].dt.dayofweek
train['_Hours'] = train['Date'].dt.hour
train['_Days'] = train['Date'].dt.day

# %%
# fazendo o mesmo para base teste

START_DATE = '2017-12-01'
start_date = datetime.datetime.strptime(START_DATE, "%Y-%m-%d")
test["Date"] = test['TransactionDT'].apply(lambda x: (start_date + datetime.timedelta
                                                             (seconds = x)))

test['_Weekdays'] = test['Date'].dt.dayofweek
test['_Hours'] = test['Date'].dt.hour
test['_Days'] = test['Date'].dt.day

# %%
# método do Pandas para mostrar todas as linhas ao pedir para exibir um dataframe
pd.reset_option('display.max_rows')

# %% [markdown]
# ## Equalizando nomes de colunas entre bases de treino e teste

# %%
# importante para seguir com ajustes na base de forma otimizada
train.columns.difference(test.columns)
# Out:
# Index(['id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06', 'id_07', 'id_08',
#        'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14', 'id_15', 'id_16',
#        'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22', 'id_23', 'id_24',
#        'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30', 'id_31', 'id_32',
#        'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38', 'isFraud'],
#       dtype='object')

# %%
# ajustar colunas de teste
test.columns = test.columns.str.replace('-', '_')

# %%
# checando resultado final das diferenças
train.columns.difference(test.columns)
# Out:
# Index(['isFraud'], dtype='object')

# %% [markdown]
# ## Tratando Colunas com Valores Faltantes

# %%
# função para checar valores NaN
def NaN_percent(df, column_name):
    #me dá a posição 0 do resultado de df.shape
    row_count = df[column_name].shape[0]
    #df.count() conta os valores não vazios
    empty_values = row_count - df[column_name].count()
    return (100.0 * empty_values)/row_count

# %%
# lista completa de colunas com percentuais de NaNs
for i in list(train):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(train,i))+'%')
# Out:
# TransactionID: 0.0%
# isFraud: 0.0%
# TransactionDT: 0.0%
# TransactionAmt: 0.0%
# ProductCD: 0.0%
# card1: 0.0%
# card2: 1.5126833068039423%
# card3: 0.26501168422122123%
# card4: 0.267043722694483%
# card5: 0.7212043214684865%
# card6: 0.26602770345785215%
# addr1: 11.12642666034477%
# addr2: 11.12642666034477%
# dist1: 59.6523520845328%
# dist2: 93.62837403054831%
# P_emaildomain: 15.99485216920107%
# R_emaildomain: 76.75161716395164%
# C1: 0.0%
# C2: 0.0%
# C3: 0.0%
# C4: 0.0%
# C5: 0.0%
# C6: 0.0%
# C7: 0.0%
# C8: 0.0%
# C9: 0.0%
# C10: 0.0%
# C11: 0.0%
# C12: 0.0%
# C13: 0.0%
# C14: 0.0%
# D1: 0.21488806854743117%
# D2: 47.54919226470688%
# D3: 44.514850814508755%
# D4: 28.604666915026925%
# D5: 52.46740271615809%
# D6: 87.60676668811597%
# D7: 93.40992989467267%
# D8: 87.31229044603245%
# D9: 87.31229044603245%
# D10: 12.873302401192129%
# D11: 47.29349409015477%
# D12: 89.04104717715988%
# D13: 89.50926270870728%
# D14: 89.46946862193924%
# D15: 15.090087038981272%
# M1: 45.90713584177194%
# M2: 45.90713584177194%
# M3: 45.90713584177194%
# M4: 47.658753005723575%
# M5: 59.34940901547736%
# M6: 28.678836319300977%
# M7: 58.63531682866529%
# M8: 58.633115453652586%
# M9: 58.633115453652586%
# V1: 47.29349409015477%
# V2: 47.29349409015477%
# V3: 47.29349409015477%
# V4: 47.29349409015477%
# V5: 47.29349409015477%
# V6: 47.29349409015477%
# V7: 47.29349409015477%
# V8: 47.29349409015477%
# V9: 47.29349409015477%
# V10: 47.29349409015477%
# V11: 47.29349409015477%
# V12: 12.881938564703491%
# V13: 12.881938564703491%
# V14: 12.881938564703491%
# V15: 12.881938564703491%
# V16: 12.881938564703491%
# V17: 12.881938564703491%
# id_02: 76.14522301622245%
# id_03: 88.76892335828225%
# id_04: 88.76892335828225%
# id_05: 76.82375452975243%
# id_06: 76.82375452975243%
# id_07: 99.12707013919463%
# id_08: 99.12707013919463%
# id_09: 87.31229044603245%
# id_10: 87.31229044603245%
# id_11: 76.12727334304196%
# id_12: 75.5760829071697%
# id_13: 78.44007179869273%
# id_14: 86.4456260371863%
# id_15: 76.12608798726589%
# id_16: 78.09801198902699%
# id_17: 76.39973583499848%
# id_18: 92.36072069631184%
# id_19: 76.40837199850984%
# id_20: 76.41802418125783%
# id_21: 99.12639279303689%
# id_22: 99.1246994276425%
# id_23: 99.1246994276425%
# id_24: 99.19615944728554%
# id_25: 99.13096487960172%
# id_26: 99.12571544687913%
# id_27: 99.1246994276425%
# id_28: 76.12727334304196%
# id_29: 76.12727334304196%
# id_30: 86.86541131845429%
# id_31: 76.24513157449114%
# id_32: 86.86185525112609%
# id_33: 87.58949436109323%
# id_34: 86.82477054898906%
# id_35: 76.12608798726589%
# id_36: 76.12608798726589%
# id_37: 76.12608798726589%
# id_38: 76.12608798726589%
# DeviceType: 76.15572188166763%
# DeviceInfo: 79.90551021099333%
# Date: 0.0%
# _Weekdays: 0.0%
# _Hours: 0.0%
# _Days: 0.0%

# %%
# identificando colunas com mais de 75% dos valores como NaN
many_null_cols_train = [col for col in train.columns if train[col].isnull().sum() / train.shape[0] > 0.75]
many_null_cols_test = [col for col in test.columns if test[col].isnull().sum() / test.shape[0] > 0.75]

# %% [markdown]
# ## Tratando Colunas com Valores Únicos

# %%
# checando se existem colunas apenas com um valor
one_value_cols_train = [col for col in train.columns if train[col].nunique() <= 1]
one_value_cols_test = [col for col in test.columns if test[col].nunique() <= 1]

print(f'There are {len(one_value_cols_train)} columns in train dataset with one unique value.')
print(f'There are {len(one_value_cols_test)} columns in test dataset with one unique value.')
# Out:
# There are 0 columns in train dataset with one unique value.
# There are 1 columns in test dataset with one unique value.

# %%
# identificando colunas com valor único
one_value_cols_train = [col for col in train.columns if train[col].nunique() <= 1]
one_value_cols_test = [col for col in test.columns if test[col].nunique() <= 1]

# %%
# checando colunas com mais de 75% de valores únicos
big_top_value_cols_train = [col for col in train.columns if \
                            train[col].value_counts(dropna=False, normalize=True).values[0] > 0.75]
big_top_value_cols_test = [col for col in test.columns if test[col].value_counts(dropna=False,\
                                                                                 normalize=True).values[0] > 0.75]

# %% [markdown]
# ## Concatenando as Colunas Desnecessárias e Removendo-as

# %%
cols_to_drop = list(set(many_null_cols_train + big_top_value_cols_train + \
                        one_value_cols_train + many_null_cols_test + big_top_value_cols_test + one_value_cols_test))

# excluir a coluna 'isFraud' da remoção
cols_to_drop.remove('isFraud')
len(cols_to_drop)
# Out:
# 346

# %%
train = train.drop(cols_to_drop, axis=1)
test = test.drop(cols_to_drop, axis=1)

# %%
# checando novamente a diferença entre colunas das bases treino e teste
train.columns.difference(test.columns)
# Out:
# Index(['isFraud'], dtype='object')

# %% [markdown]
# ## Identificando Linhas com Valores Faltantes e Removendo-as

# %%
# checando e excluindo linhas com mais de 75% de valores faltantes
perc = 75.0 
min_count =  int(((100 - perc) / 100) * train.shape[1] + 1)
train = train.dropna(axis = 0, thresh = min_count)

min_count =  int(((100 - perc) / 100) * test.shape[1] + 1)
test = test.dropna(axis = 0, thresh = min_count)

# %%
train.shape
# Out:
# (590540, 92)

# %%
test.shape
# Out:
# (506691, 91)

# %% [markdown]
# ## Remover colunas datetime e ID para balanceamento e redução de dimensionalidade

# %%
# remover TransactionID e datetime para balanceamento e redução de dimensionalidade
train = train.drop(['TransactionID', 'TransactionDT', 'Date'], axis = 1)
test = test.drop(['TransactionID', 'TransactionDT', 'Date'], axis = 1)

# %%
# checando por diferenças de colunas entre as bases de treino e teste
train.columns.difference(test.columns)
# Out:
# Index(['isFraud'], dtype='object')

# %% [markdown]
# ## Substituindo NaNs remanescentes por média (variáveis numéricas) e moda (variáveis categóricas) para pacotes de balanceamento e redução de dimensionalidade

# %%
# lista completa de colunas remanescentes com percentuais de NaNs
for i in list(train):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(train,i))+'%')
# Out:
# isFraud: 0.0%
# TransactionAmt: 0.0%
# ProductCD: 0.0%
# card1: 0.0%
# card2: 1.5126833068039423%
# card4: 0.267043722694483%
# card5: 0.7212043214684865%
# addr1: 11.12642666034477%
# dist1: 59.6523520845328%
# P_emaildomain: 15.99485216920107%
# C1: 0.0%
# C2: 0.0%
# C5: 0.0%
# C6: 0.0%
# C9: 0.0%
# C11: 0.0%
# C13: 0.0%
# C14: 0.0%
# D1: 0.21488806854743117%
# D2: 47.54919226470688%
# D3: 44.514850814508755%
# D4: 28.604666915026925%
# D5: 52.46740271615809%
# D10: 12.873302401192129%
# D11: 47.29349409015477%
# D15: 15.090087038981272%
# M1: 45.90713584177194%
# M2: 45.90713584177194%
# M3: 45.90713584177194%
# M4: 47.658753005723575%
# M5: 59.34940901547736%
# M6: 28.678836319300977%
# M7: 58.63531682866529%
# M8: 58.633115453652586%
# M9: 58.633115453652586%
# V1: 47.29349409015477%
# V2: 47.29349409015477%
# V3: 47.29349409015477%
# V4: 47.29349409015477%
# V5: 47.29349409015477%
# V6: 47.29349409015477%
# V7: 47.29349409015477%
# V8: 47.29349409015477%
# V9: 47.29349409015477%
# V10: 47.29349409015477%
# V11: 47.29349409015477%
# V12: 12.881938564703491%
# V13: 12.881938564703491%
# V29: 12.881938564703491%
# V30: 12.881938564703491%
# V35: 28.612625732380533%
# V36: 28.612625732380533%
# V39: 28.612625732380533%
# V40: 28.612625732380533%
# V42: 28.612625732380533%
# V43: 28.612625732380533%
# V48: 28.612625732380533%
# V49: 28.612625732380533%
# V50: 28.612625732380533%
# V51: 28.612625732380533%
# V52: 28.612625732380533%
# V53: 13.055169844549058%
# V54: 13.055169844549058%
# V69: 13.055169844549058%
# V70: 13.055169844549058%
# V75: 15.098723202492634%
# V76: 15.098723202492634%
# V80: 15.098723202492634%
# V81: 15.098723202492634%
# V84: 15.098723202492634%
# V85: 15.098723202492634%
# V90: 15.098723202492634%
# V91: 15.098723202492634%
# V92: 15.098723202492634%
# V93: 15.098723202492634%
# V96: 0.053171673383682734%
# V99: 0.053171673383682734%
# V127: 0.053171673383682734%
# V130: 0.053171673383682734%
# V280: 0.0020320384732617604%
# V282: 0.21488806854743117%
# V283: 0.21488806854743117%
# V285: 0.0020320384732617604%
# V307: 0.0020320384732617604%
# V308: 0.0020320384732617604%
# V310: 0.0020320384732617604%
# _Weekdays: 0.0%
# _Hours: 0.0%
# _Days: 0.0%

# %%
# das colunas com NaNs remanescentes, entender quais são de variáveis numéricas ou categóricas
pd.options.display.max_rows = 999
resumetable(train)
# Out:
# Dataset Shape: (590540, 89)
#               Name   dtypes  Missing  Uniques First Value Second Value  \
# 0          isFraud    int64        0        2           0            0
# 1   TransactionAmt  float64        0    20902        68.5         29.0
# 2        ProductCD   object        0        5           W            W
# 3            card1    int64        0    13553       13926         2755
# 4            card2  float64     8933      500         NaN        404.0
# 5            card4   object     1577        4    discover   mastercard
# 6            card5  float64     4259      119       142.0        102.0
# 7            addr1  float64    65706      332       315.0        325.0
# 8            dist1  float64   352271     2651        19.0          NaN
# 9    P_emaildomain   object    94456       59         NaN    gmail.com
# 10              C1  float64        0     1657         1.0          1.0
# 11              C2  float64        0     1216         1.0          1.0
# 12              C5  float64        0      319         0.0          0.0
# 13              C6  float64        0     1328         1.0          1.0
# 14              C9  float64        0      205         1.0          0.0
# 15             C11  float64        0     1476         2.0          1.0
# 16             C13  float64        0     1597         1.0          1.0
# 17             C14  float64        0     1108         1.0          1.0
# 18              D1  float64     1269      641        14.0          0.0
# 19              D2  float64   280797      641         NaN          NaN
# 20              D3  float64   262878      649        13.0          NaN
# 21              D4  float64   168922      808         NaN          0.0
# 22              D5  float64   309841      688         NaN          NaN
# 23             D10  float64    76022      818        13.0          0.0
# 24             D11  float64   279287      676        13.0          NaN
# 25             D15  float64    89113      859         0.0          0.0
# 26              M1   object   271100        2           T          NaN
# 27              M2   object   271100        2           T          NaN
# 28              M3   object   271100        2           T          NaN
# 29              M4   object   281444        3          M2           M0
# 30              M5   object   350482        2           F            T
# 31              M6   object   169360        2           T            T
# 32              M7   object   346265        2         NaN          NaN
# 33              M8   object   346252        2         NaN          NaN
# 34              M9   object   346252        2         NaN          NaN
# 35              V1  float64   279287        2         1.0          NaN
# 36              V2  float64   279287        9         1.0          NaN
# 37              V3  float64   279287       10         1.0          NaN
# 38              V4  float64   279287        7         1.0          NaN
# 39              V5  float64   279287        7         1.0          NaN
# 40              V6  float64   279287       10         1.0          NaN
# 41              V7  float64   279287       10         1.0          NaN
# 42              V8  float64   279287        9         1.0          NaN
# 43              V9  float64   279287        9         1.0          NaN
# 44             V10  float64   279287        5         0.0          NaN
# 45             V11  float64   279287        6         0.0          NaN
# 46             V12  float64    76073        4         1.0          0.0
# 47             V13  float64    76073        7         1.0          0.0
# 48             V29  float64    76073        6         0.0          0.0
# 49             V30  float64    76073        8         0.0          0.0
# 50             V35  float64   168969        4         NaN          0.0
# 51             V36  float64   168969        6         NaN          0.0
# 52             V39  float64   168969       16         NaN          0.0
# 53             V40  float64   168969       18         NaN          0.0
# 54             V42  float64   168969        9         NaN          0.0
# 55             V43  float64   168969        9         NaN          0.0
# 56             V48  float64   168969        6         NaN          0.0
# 57             V49  float64   168969        6         NaN          0.0
# 58             V50  float64   168969        6         NaN          0.0
# 59             V51  float64   168969        7         NaN          0.0
# 60             V52  float64   168969        9         NaN          0.0
# 61             V53  float64    77096        6         1.0          0.0
# 62             V54  float64    77096        7         1.0          0.0
# 63             V69  float64    77096        6         0.0          0.0
# 64             V70  float64    77096        7         0.0          0.0
# 65             V75  float64    89164        5         1.0          0.0
# 66             V76  float64    89164        7         1.0          0.0
# 67             V80  float64    89164       20         0.0          0.0
# 68             V81  float64    89164       20         0.0          0.0
# 69             V84  float64    89164        8         0.0          0.0
# 70             V85  float64    89164        8         0.0          0.0
# 71             V90  float64    89164        6         0.0          0.0
# 72             V91  float64    89164        7         0.0          0.0
# 73             V92  float64    89164        8         0.0          0.0
# 74             V93  float64    89164        8         0.0          0.0
# 75             V96  float64      314     1410         1.0          0.0
# 76             V99  float64      314       89         0.0          0.0
# 77            V127  float64      314    24414       117.0          0.0
# 78            V130  float64      314    12332         0.0          0.0
# 79            V280  float64       12      975         0.0          0.0
# 80            V282  float64     1269       33         1.0          1.0
# 81            V283  float64     1269       62         1.0          1.0
# 82            V285  float64       12       96         0.0          0.0
# 83            V307  float64       12    37367       117.0          0.0
# 84            V308  float64       12    23064         0.0          0.0
# 85            V310  float64       12    19136         0.0          0.0
# 86       _Weekdays    int32        0        7           5            5
# 87          _Hours    int32        0       24           0            0
# 88           _Days    int32        0       31           2            2
#
#     Third Value            Entropy
# 0             0  0.220000000000000
# 1          59.0  8.350000000000000
# 2             W  1.280000000000000
# 3          4663  9.970000000000001
# 4         490.0  6.320000000000000
# 5          visa  1.090000000000000
# 6         166.0  2.660000000000000
# 7         330.0  5.060000000000000
# 8         287.0  6.340000000000000
# 9   outlook.com  2.680000000000000
# 10          1.0  2.720000000000000
# 11          1.0  2.750000000000000
# 12          0.0  2.060000000000000
# 13          1.0  2.520000000000000
# 14          1.0  2.620000000000000
# 15          1.0  2.170000000000000
# 16          1.0  4.660000000000000
# 17          1.0  2.670000000000000
# 18          0.0  5.570000000000000
# 19          NaN  8.570000000000000
# 20          NaN  5.600000000000000
# 21          0.0  6.420000000000000
# 22          NaN  5.950000000000000
# 23          0.0  6.090000000000000
# 24        315.0  6.730000000000000
# 25        315.0  6.880000000000000
# 26            T  0.000000000000000
# 27            T  0.490000000000000
# 28            T  0.750000000000000
# 29           M0  1.310000000000000
# 30            F  0.990000000000000
# 31            F  1.000000000000000
# 32            F  0.570000000000000
# 33            F  0.950000000000000
# 34            F  0.630000000000000
# 35          1.0  0.000000000000000
# 36          1.0  0.270000000000000
# 37          1.0  0.400000000000000
# 38          1.0  0.860000000000000
# 39          1.0  0.950000000000000
# 40          1.0  0.270000000000000
# 41          1.0  0.380000000000000
# 42          1.0  0.180000000000000
# 43          1.0  0.250000000000000
# 44          0.0  1.070000000000000
# 45          0.0  1.130000000000000
# 46          1.0  1.050000000000000
# 47          1.0  1.110000000000000
# 48          0.0  1.030000000000000
# 49          0.0  1.100000000000000
# 50          1.0  1.060000000000000
# 51          1.0  1.130000000000000
# 52          0.0  0.670000000000000
# 53          0.0  0.710000000000000
# 54          0.0  0.650000000000000
# 55          0.0  0.690000000000000
# 56          0.0  1.020000000000000
# 57          0.0  1.080000000000000
# 58          0.0  0.650000000000000
# 59          0.0  0.690000000000000
# 60          0.0  0.730000000000000
# 61          1.0  1.050000000000000
# 62          1.0  1.120000000000000
# 63          0.0  1.030000000000000
# 64          0.0  1.100000000000000
# 65          1.0  1.060000000000000
# 66          1.0  1.120000000000000
# 67          0.0  0.610000000000000
# 68          0.0  0.640000000000000
# 69          0.0  0.590000000000000
# 70          0.0  0.640000000000000
# 71          0.0  1.040000000000000
# 72          0.0  1.110000000000000
# 73          0.0  0.630000000000000
# 74          0.0  0.650000000000000
# 75          0.0  2.040000000000000
# 76          0.0  1.690000000000000
# 77          0.0  5.050000000000000
# 78          0.0  4.090000000000000
# 79          0.0  1.540000000000000
# 80          1.0  1.520000000000000
# 81          1.0  1.790000000000000
# 82          0.0  1.990000000000000
# 83          0.0  6.330000000000000
# 84          0.0  3.840000000000000
# 85          0.0  5.260000000000000
# 86            5  2.800000000000000
# 87            0  4.260000000000000
# 88            2  4.940000000000000

# %%
# função para substituir os valores faltantes, usando média para variáveis numéricas e moda para variáveis categóricas
def replace_missing_values(df, numeric_strategy='mean', categorical_strategy='mode'):
    """
    Substitui valores ausentes em um DataFrame.
    
    Parâmetros:
    - df: O DataFrame contendo os dados.
    - numeric_strategy: A estratégia de substituição para colunas numéricas ('mean' ou 'median').
    - categorical_strategy: A estratégia de substituição para colunas categóricas ('mode' ou 'random').
    
    Retorna:
    - Um novo DataFrame com os valores ausentes substituídos.
    """
    df_copy = df.copy()
    
    # Lidar com colunas numéricas
    numeric_cols = df_copy.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        if numeric_strategy == 'mean':
            df_copy[col].fillna(df_copy[col].mean(), inplace=True)
        elif numeric_strategy == 'median':
            df_copy[col].fillna(df_copy[col].median(), inplace=True)
    
    # Lidar com colunas categóricas
    categorical_cols = df_copy.select_dtypes(exclude=[np.number]).columns
    for col in categorical_cols:
        if categorical_strategy == 'mode':
            df_copy[col].fillna(df_copy[col].mode()[0], inplace=True)
        elif categorical_strategy == 'random':
            df_copy[col].fillna(df_copy[col].sample(1).iloc[0], inplace=True)
    
    return df_copy

# %%
train = replace_missing_values(train)

# %%
# checando mais uma vez as colunas remanescentes com percentuais de NaNs
for i in list(train):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(train,i))+'%')
# Out:
# isFraud: 0.0%
# TransactionAmt: 0.0%
# ProductCD: 0.0%
# card1: 0.0%
# card2: 0.0%
# card4: 0.0%
# card5: 0.0%
# addr1: 0.0%
# dist1: 0.0%
# P_emaildomain: 0.0%
# C1: 0.0%
# C2: 0.0%
# C5: 0.0%
# C6: 0.0%
# C9: 0.0%
# C11: 0.0%
# C13: 0.0%
# C14: 0.0%
# D1: 0.0%
# D2: 0.0%
# D3: 0.0%
# D4: 0.0%
# D5: 0.0%
# D10: 0.0%
# D11: 0.0%
# D15: 0.0%
# M1: 0.0%
# M2: 0.0%
# M3: 0.0%
# M4: 0.0%
# M5: 0.0%
# M6: 0.0%
emaildomain', 'M1', 'M2', 'M3', 'M4', 'M5',
#        'M6', 'M7', 'M8', 'M9'],
#       dtype='object')

# %%
# pela documentação do conjunto de dados, nenhuma delas é categórica ordinal
# separando as colunas a serem tratadas
object_columns_treated = ['ProductCD', 'card4', 'P_emaildomain', 'M1', 'M2', 'M3', 'M4',
       'M5', 'M6', 'M7', 'M8', 'M9']

# %%
# Aplicando One-Hot Encoding em várias colunas
train = pd.get_dummies(train, columns = object_columns_treated)
test = pd.get_dummies(test, columns = object_columns_treated)

# %%
# checando se ainda existem colunas "object"
checking_remaining_objects_train = resumetable(train)[['Name', 'dtypes']]
checking_remaining_objects_train[checking_remaining_objects_train['dtypes'] == 'object']
# Out:
# Dataset Shape: (590540, 164)
# Empty DataFrame
# Columns: [Name, dtypes]
# Index: []

# %%
# checando se ainda existem colunas "object"
checking_remaining_objects_test = resumetable(test)[['Name', 'dtypes']]
checking_remaining_objects_test[checking_remaining_objects_test['dtypes'] == 'object']
# Out:
# Dataset Shape: (506691, 164)
# Empty DataFrame
# Columns: [Name, dtypes]
# Index: []

# %%
# checando se ainda existem colunas categóricas
cols = train.columns
num_cols = train._get_numeric_data().columns
cat_cols = list(set(cols) - set(num_cols))
cat_cols
# Out:
# []

# %%
# checando se ainda existem colunas categóricas
cols = test.columns
num_cols = test._get_numeric_data().columns
cat_cols = list(set(cols) - set(num_cols))
cat_cols
# Out:
# []

# %%
# checando por diferenças entre as colunas de treino e teste
train.columns.difference(test.columns)
# Out:
# Index(['isFraud'], dtype='object')

# %% [markdown]
# ## Checando colunas com valores negativos para métodos de seleção de atributos

# %%
columns_negative_values = train.columns[train.lt(0).any()]
print("Columns with negative values:", columns_negative_values)
# Out:
# Columns with negative values: Index(['D4', 'D11', 'D15'], dtype='object')

# %%
# separando as columas com valores negativos
negative_columns_treated = ['D4', 'D11', 'D15']

# %%
# realizando a transformação
le = LabelEncoder()
for col in negative_columns_treated:
    if col in train.columns:
        le.fit(list(train[col].astype(str).values) + list(test[col].astype(str).values))
        train[col] = le.fit_transform(list(train[col].astype(str).values))
        test[col] = le.fit_transform(list(test[col].astype(str).values))

# %%
# última checagem de valores negativos
columns_negative_values = train.columns[train.lt(0).any()]
print("Columns with negative values:", columns_negative_values)
# Out:
# Columns with negative values: Index([], dtype='object')

# %%
# última checagem de valores negativos
columns_negative_values = test.columns[test.lt(0).any()]
print("Columns with negative values:", columns_negative_values)
# Out:
# Columns with negative values: Index([], dtype='object')

# %% [markdown]
# # Separação da base de treino entre treino e teste para balanceamento e avaliação de desempenho dos algoritmos de ML (Dataset 01)

# %%
# Separar entre treinamento e teste com estratificação (80% para treinamento, 20% para teste)
train_split, test_split = train_test_split(train, test_size=0.2, random_state=42, stratify = train.isFraud)

# %%
# Separar entre treinamento e teste com estratificação (80% para treinamento, 20% para teste)
X_train = train_split.drop('isFraud',axis = 1)
y_train = train_split['isFraud'].astype('uint8')

X_test = test_split.drop('isFraud', axis = 1)
y_test = test_split['isFraud'].astype('uint8')

# %%
# Exibir a distribuição das classes nos conjuntos de treinamento e teste
print("Distribuição das classes no conjunto de treinamento:")
print(y_train.value_counts())

print("\nDistribuição das classes no conjunto de teste:")
print(y_test.value_counts())
# Out:
# Distribuição das classes no conjunto de treinamento:
# isFraud
# 0    455902
# 1     16530
# Name: count, dtype: int64
#
# Distribuição das classes no conjunto de teste:
# isFraud
# 0    113975
# 1      4133
# Name: count, dtype: int64

# %%
# combinando as classes minoritária com a majoritária subamostrada
test_split = pd.concat([X_test, y_test], \
                                       axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
test_split.isFraud.value_counts()
# Out:
# isFraud
# 0    113975
# 1      4133
# Name: count, dtype: int64

# %% [markdown]
# # Feature Engineering (Dataset 02)

# %% [markdown]
# ## Convertendo "TransactionDT" em data, dias, horários e dias da semana

# %%
# a primeira data é 01/12/2017 e será usada o timedelta para calcular os atributos de 
# datas e horários

#import datetime

#START_DATE = '2017-12-01'
#start_date = datetime.datetime.strptime(START_DATE, "%Y-%m-%d")
#train["Date"] = train['TransactionDT'].apply(lambda x: (start_date + datetime.timedelta
#                                                             (seconds = x)))

#train['_Weekdays'] = train['Date'].dt.dayofweek
#train['_Hours'] = train['Date'].dt.hour
#train['_Days'] = train['Date'].dt.day

# %%
# fazendo o mesmo para base teste

#START_DATE = '2017-12-01'
#start_date = datetime.datetime.strptime(START_DATE, "%Y-%m-%d")
#test["Date"] = test['TransactionDT'].apply(lambda x: (start_date + datetime.timedelta
#                                                             (seconds = x)))

#test['_Weekdays'] = test['Date'].dt.dayofweek
#test['_Hours'] = test['Date'].dt.hour
#test['_Days'] = test['Date'].dt.day

# %%
# método do Pandas para mostrar todas as linhas ao pedir para exibir um dataframe
#pd.reset_option('display.max_rows')

# %% [markdown]
# ## Equalizando nomes de colunas entre bases de treino e teste

# %%
# importante para seguir com ajustes na base de forma otimizada
#train.columns.difference(test.columns)

# %%
# ajustar colunas de teste
#test.columns = test.columns.str.replace('-', '_')

# %%
# checando resultado final das diferenças
#train.columns.difference(test.columns)

# %% [markdown]
# ## Tratando Colunas com Valores Faltantes

# %%
# função para checar valores NaN
def NaN_percent(df, column_name):
    #me dá a posição 0 do resultado de df.shape
    row_count = df[column_name].shape[0]
    #df.count() conta os valores não vazios
    empty_values = row_count - df[column_name].count()
    return (100.0 * empty_values)/row_count

# %%
# lista completa de colunas com percentuais de NaNs
for i in list(creditcard):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(creditcard,i))+'%')
# Out:
# Time: 0.0%
# V1: 0.0%
# V2: 0.0%
# V3: 0.0%
# V4: 0.0%
# V5: 0.0%
# V6: 0.0%
# V7: 0.0%
# V8: 0.0%
# V9: 0.0%
# V10: 0.0%
# V11: 0.0%
# V12: 0.0%
# V13: 0.0%
# V14: 0.0%
# V15: 0.0%
# V16: 0.0%
# V17: 0.0%
# V18: 0.0%
# V19: 0.0%
# V20: 0.0%
# V21: 0.0%
# V22: 0.0%
# V23: 0.0%
# V24: 0.0%
# V25: 0.0%
# V26: 0.0%
# V27: 0.0%
# V28: 0.0%
# Amount: 0.0%
# Class: 0.0%

# %%
# identificando colunas com mais de 75% dos valores como NaN
many_null_cols_creditcard = [col for col in creditcard.columns if creditcard[col].isnull().sum() / creditcard.shape[0] > 0.75]
#many_null_cols_test = [col for col in test.columns if test[col].isnull().sum() / test.shape[0] > 0.75]

# %% [markdown]
# ## Tratando Colunas com Valores Únicos

# %%
# checando se existem colunas apenas com um valor
one_value_cols_creditcard = [col for col in creditcard.columns if creditcard[col].nunique() <= 1]
#one_value_cols_test = [col for col in test.columns if test[col].nunique() <= 1]

print(f'There are {len(one_value_cols_creditcard)} columns in creditcard dataset with one unique value.')
#print(f'There are {len(one_value_cols_test)} columns in test dataset with one unique value.')
# Out:
# There are 0 columns in creditcard dataset with one unique value.

# %%
# identificando colunas com valor único
one_value_cols_creditcard = [col for col in creditcard.columns if creditcard[col].nunique() <= 1]
#one_value_cols_test = [col for col in test.columns if test[col].nunique() <= 1]

# %%
# checando colunas com mais de 75% de valores únicos
big_top_value_cols_creditcard = [col for col in creditcard.columns if \
                            creditcard[col].value_counts(dropna=False, normalize=True).values[0] > 0.75]
#big_top_value_cols_test = [col for col in test.columns if test[col].value_counts(dropna=False,\
#                                                                                 normalize=True).values[0] > 0.75]

# %% [markdown]
# ## Concatenando as Colunas Desnecessárias e Removendo-as

# %%
cols_to_drop = list(set(many_null_cols_creditcard + big_top_value_cols_creditcard + \
                        one_value_cols_creditcard))# + many_null_cols_test + big_top_value_cols_test + one_value_cols_test))

# excluir a coluna 'Class' da remoção
cols_to_drop.remove('Class')
len(cols_to_drop)
# Out:
# 0

# %%
creditcard = creditcard.drop(cols_to_drop, axis=1)
#test = test.drop(cols_to_drop, axis=1)

# %%
# checando novamente a diferença entre colunas das bases treino e teste
#train.columns.difference(test.columns)

# %% [markdown]
# ## Identificando Linhas com Valores Faltantes e Removendo-as

# %%
# checando e excluindo linhas com mais de 75% de valores faltantes
perc = 75.0 
min_count =  int(((100 - perc) / 100) * creditcard.shape[1] + 1)
creditcard = creditcard.dropna(axis = 0, thresh = min_count)

#min_count =  int(((100 - perc) / 100) * test.shape[1] + 1)
#test = test.dropna(axis = 0, thresh = min_count)

# %%
creditcard.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## Remover colunas datetime e ID para balanceamento e redução de dimensionalidade

# %%
# remover TransactionID e datetime para balanceamento e redução de dimensionalidade
#train = train.drop(['TransactionID', 'TransactionDT', 'Date'], axis = 1)
#test = test.drop(['TransactionID', 'TransactionDT', 'Date'], axis = 1)

# %%
# checando por diferenças de colunas entre as bases de treino e teste
#train.columns.difference(test.columns)

# %% [markdown]
# ## Substituindo NaNs remanescentes por média (variáveis numéricas) e moda (variáveis categóricas) para pacotes de balanceamento e redução de dimensionalidade

# %%
# lista completa de colunas remanescentes com percentuais de NaNs
for i in list(creditcard):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(creditcard,i))+'%')
# Out:
# Time: 0.0%
# V1: 0.0%
# V2: 0.0%
# V3: 0.0%
# V4: 0.0%
# V5: 0.0%
# V6: 0.0%
# V7: 0.0%
# V8: 0.0%
# V9: 0.0%
# V10: 0.0%
# V11: 0.0%
# V12: 0.0%
# V13: 0.0%
# V14: 0.0%
# V15: 0.0%
# V16: 0.0%
# V17: 0.0%
# V18: 0.0%
# V19: 0.0%
# V20: 0.0%
# V21: 0.0%
# V22: 0.0%
# V23: 0.0%
# V24: 0.0%
# V25: 0.0%
# V26: 0.0%
# V27: 0.0%
# V28: 0.0%
# Amount: 0.0%
# Class: 0.0%

# %%
# das colunas com NaNs remanescentes, entender quais são de variáveis numéricas ou categóricas
pd.options.display.max_rows = 999
resumetable(creditcard)
# Out:
# Dataset Shape: (284807, 31)
#       Name   dtypes  Missing  Uniques          First Value       Second Value  \
# 0     Time  float64        0   124592    0.000000000000000  0.000000000000000
# 1       V1  float64        0   275663   -1.359807133673800  1.191857111314860
# 2       V2  float64        0   275663   -0.072781173309850  0.266150712059630
# 3       V3  float64        0   275663    2.536346737969140  0.166480113353210
# 4       V4  float64        0   275663    1.378155224274430  0.448154078460911
# 5       V5  float64        0   275663   -0.338320769942518  0.060017649282224
# 6       V6  float64        0   275663    0.462387777762292 -0.082360808815569
# 7       V7  float64        0   275663    0.239598554061257 -0.078802983332311
# 8       V8  float64        0   275663    0.098697901261051  0.085101654914810
# 9       V9  float64        0   275663    0.363786969611213 -0.255425128109186
# 10     V10  float64        0   275663    0.090794171978932 -0.166974414004614
# 11     V11  float64        0   275663   -0.551599533260813  1.612726661054790
# 12     V12  float64        0   275663   -0.617800855762348  1.065235311372870
# 13     V13  float64        0   275663   -0.991389847235408  0.489095015896080
# 14     V14  float64        0   275663   -0.311169353699879 -0.143772296441519
# 15     V15  float64        0   275663    1.468176972094270  0.635558093258208
# 16     V16  float64        0   275663   -0.470400525259478  0.463917041022171
# 17     V17  float64        0   275663    0.207971241929242 -0.114804663102346
# 18     V18  float64        0   275663    0.025790580198559 -0.183361270123994
# 19     V19  float64        0   275663    0.403992960255733 -0.145783041325259
# 20     V20  float64        0   275663    0.251412098239705 -0.069083135223020
# 21     V21  float64        0   275663   -0.018306777944153 -0.225775248033138
# 22     V22  float64        0   275663    0.277837575558899 -0.638671952771851
# 23     V23  float64        0   275663   -0.110473910188767  0.101288021253234
# 24     V24  float64        0   275663    0.066928074914673 -0.339846475529127
# 25     V25  float64        0   275663    0.128539358273528  0.167170404418143
# 26     V26  float64        0   275663   -0.189114843888824  0.125894532368176
# 27     V27  float64        0   275663    0.133558376740387 -0.008983099143228
# 28     V28  float64        0   275663   -0.021053053453821  0.014724169192493
# 29  Amount  float64        0    32767  149.620000000000005  2.690000000000000
# 30   Class    int64        0        2    0.000000000000000  0.000000000000000
#
#             Third Value             Entropy
# 0     1.000000000000000  16.690000000000001
# 1    -1.358354061598230  18.030000000000001
# 2    -1.340163074736090  18.030000000000001
# 3     1.773209342631190  18.030000000000001
# 4     0.379779593034328  18.030000000000001
# 5    -0.503198133318193  18.030000000000001
# 6     1.800499380792630  18.030000000000001
# 7     0.791460956450422  18.030000000000001
# 8     0.247675786588991  18.030000000000001
# 9    -1.514654322605830  18.030000000000001
# 10    0.207642865216696  18.030000000000001
# 11    0.624501459424895  18.030000000000001
# 12    0.066083685268831  18.030000000000001
# 13    0.717292731410831  18.030000000000001
# 14   -0.165945922763554  18.030000000000001
# 15    2.345864949015810  18.030000000000001
# 16   -2.890083194442310  18.030000000000001
# 17    1.109969378695990  18.030000000000001
# 18   -0.121359313195888  18.030000000000001
# 19   -2.261857095304140  18.030000000000001
# 20    0.524979725224404  18.030000000000001
# 21    0.247998153469754  18.030000000000001
# 22    0.771679401917229  18.030000000000001
# 23    0.909412262347719  18.030000000000001
# 24   -0.689280956490685  18.030000000000001
# 25   -0.327641833735251  18.030000000000001
# 26   -0.139096571514147  18.030000000000001
# 27   -0.055352794038426  18.030000000000001
# 28   -0.059751840592920  18.030000000000001
# 29  378.660000000000025  11.500000000000000
# 30    0.000000000000000   0.020000000000000

# %%
# função para substituir os valores faltantes, usando média para variáveis numéricas e moda para variáveis categóricas
def replace_missing_values(df, numeric_strategy='mean', categorical_strategy='mode'):
    """
    Substitui valores ausentes em um DataFrame.
    
    Parâmetros:
    - df: O DataFrame contendo os dados.
    - numeric_strategy: A estratégia de substituição para colunas numéricas ('mean' ou 'median').
    - categorical_strategy: A estratégia de substituição para colunas categóricas ('mode' ou 'random').
    
    Retorna:
    - Um novo DataFrame com os valores ausentes substituídos.
    """
    df_copy = df.copy()
    
    # Lidar com colunas numéricas
    numeric_cols = df_copy.select_dtypes(include=[np.number]).columns
    for col in numeric_cols:
        if numeric_strategy == 'mean':
            df_copy[col].fillna(df_copy[col].mean(), inplace=True)
        elif numeric_strategy == 'median':
            df_copy[col].fillna(df_copy[col].median(), inplace=True)
    
    # Lidar com colunas categóricas
    categorical_cols = df_copy.select_dtypes(exclude=[np.number]).columns
    for col in categorical_cols:
        if categorical_strategy == 'mode':
            df_copy[col].fillna(df_copy[col].mode()[0], inplace=True)
        elif categorical_strategy == 'random':
            df_copy[col].fillna(df_copy[col].sample(1).iloc[0], inplace=True)
    
    return df_copy

# %%
creditcard = replace_missing_values(creditcard)

# %%
# checando mais uma vez as colunas remanescentes com percentuais de NaNs
for i in list(creditcard):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(creditcard,i))+'%')
# Out:
# Time: 0.0%
# V1: 0.0%
# V2: 0.0%
# V3: 0.0%
# V4: 0.0%
# V5: 0.0%
# V6: 0.0%
# V7: 0.0%
# V8: 0.0%
# V9: 0.0%
# V10: 0.0%
# V11: 0.0%
# V12: 0.0%
# V13: 0.0%
# V14: 0.0%
# V15: 0.0%
# V16: 0.0%
# V17: 0.0%
# V18: 0.0%
# V19: 0.0%
# V20: 0.0%
# V21: 0.0%
# V22: 0.0%
# V23: 0.0%
# V24: 0.0%
# V25: 0.0%
# V26: 0.0%
# V27: 0.0%
# V28: 0.0%
# Amount: 0.0%
# Class: 0.0%

# %%
#test = replace_missing_values(test)

# %%
# checando mais uma vez as colunas remanescentes com percentuais de NaNs
for i in list(creditcard):
    #str() converte número em string
    print(i + ': ' + str(NaN_percent(creditcard,i))+'%')
# Out:
# Time: 0.0%
# V1: 0.0%
# V2: 0.0%
# V3: 0.0%
# V4: 0.0%
# V5: 0.0%
# V6: 0.0%
# V7: 0.0%
# V8: 0.0%
# V9: 0.0%
# V10: 0.0%
# V11: 0.0%
# V12: 0.0%
# V13: 0.0%
# V14: 0.0%
# V15: 0.0%
# V16: 0.0%
# V17: 0.0%
# V18: 0.0%
# V19: 0.0%
# V20: 0.0%
# V21: 0.0%
# V22: 0.0%
# V23: 0.0%
# V24: 0.0%
# V25: 0.0%
# V26: 0.0%
# V27: 0.0%
# V28: 0.0%
# Amount: 0.0%
# Class: 0.0%

# %% [markdown]
# ## Codificação de variáveis categóricas (para pacotes de redução de dimensionalidade)

# %%
# identificando os atributos classificados como "object" para codificação
object_columns = creditcard.select_dtypes(include = "object").columns
print(object_columns)
# Out:
# Index([], dtype='object')

# %%
# pela documentação do conjunto de dados, nenhuma delas é categórica ordinal
# separando as colunas a serem tratadas
#object_columns_treated = ['ProductCD', 'card4', 'P_emaildomain', 'M1', 'M2', 'M3', 'M4',
#       'M5', 'M6', 'M7', 'M8', 'M9']

# %%
# Aplicando One-Hot Encoding em várias colunas
#creditcard = pd.get_dummies(creditcard, columns = object_columns_treated)
#test = pd.get_dummies(test, columns = object_columns_treated)

# %%
# checando se ainda existem colunas "object"
checking_remaining_objects_creditcard = resumetable(creditcard)[['Name', 'dtypes']]
checking_remaining_objects_creditcard[checking_remaining_objects_creditcard['dtypes'] == 'object']
# Out:
# Dataset Shape: (284807, 31)
# Empty DataFrame
# Columns: [Name, dtypes]
# Index: []

# %%
# checando se ainda existem colunas "object"
#checking_remaining_objects_test = resumetable(test)[['Name', 'dtypes']]
#checking_remaining_objects_test[checking_remaining_objects_test['dtypes'] == 'object']

# %%
# checando se ainda existem colunas categóricas
cols = creditcard.columns
num_cols = creditcard._get_numeric_data().columns
cat_cols = list(set(cols) - set(num_cols))
cat_cols
# Out:
# []

# %%
# checando se ainda existem colunas categóricas
#cols = test.columns
#num_cols = test._get_numeric_data().columns
#cat_cols = list(set(cols) - set(num_cols))
#cat_cols

# %%
# checando por diferenças entre as colunas de treino e teste
#train.columns.difference(test.columns)

# %% [markdown]
# ## Checando colunas com valores negativos para métodos de seleção de atributos

# %%
columns_negative_values = creditcard.columns[creditcard.lt(0).any()]
print("Columns with negative values:", columns_negative_values)
# Out:
# Columns with negative values: Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
# separando as columas com valores negativos
#negative_columns_treated = ['D4', 'D11', 'D15']

# %%
# última checagem de valores negativos
columns_negative_values = creditcard.columns[creditcard.lt(0).any()]
print("Columns with negative values:", columns_negative_values)
# Out:
# Columns with negative values: Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28'],
#       dtype='object')

# %%
# última checagem de valores negativos
#columns_negative_values = test.columns[test.lt(0).any()]
#print("Columns with negative values:", columns_negative_values)

# %% [markdown]
# # Separação da base de treino entre treino e teste para balanceamento e avaliação de desempenho dos algoritmos de ML (Dataset 02)

# %%
# Separar entre treinamento e teste com estratificação (80% para treinamento, 20% para teste)
#train_split, test_split = train_test_split(creditcard, test_size=0.2, random_state=42, stratify = creditcard.Class)

# %%
# Separar entre treinamento e teste com estratificação (80% para treinamento, 20% para teste)
#X_train = train_split.drop('Class',axis = 1)
#y_train = train_split['Class'].astype('uint8')

#X_test = test_split.drop('Class', axis = 1)
#y_test = test_split['Class'].astype('uint8')

# %%
# Exibir a distribuição das classes nos conjuntos de treinamento e teste
#print("Distribuição das classes no conjunto de treinamento:")
#print(y_train.value_counts())

#print("\nDistribuição das classes no conjunto de teste:")
#print(y_test.value_counts())

# %%
# combinando as classes minoritária com a majoritária subamostrada
#test_split = pd.concat([X_test, y_test], \
#                                       axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
#test_split.Class.value_counts()

# %% [markdown]
# # Balanceamento de Classes (Datasets 01 e 02)

# %% [markdown]
# ### Undersample com Resample

# %%
# %%time

from sklearn.utils import resample

#not_fraud = train_split[train_split.Class == 0]
#fraud = train_split[train_split.Class == 1]

not_fraud = train_split[train_split.isFraud == 0]
fraud = train_split[train_split.isFraud == 1]


not_fraud_undersampled = resample(not_fraud,
                                  replace = False, # sample without replacement
                                  n_samples = len(fraud), # match minority n
                                  random_state = 0)



# combinando as classes minoritária com majoritária subamostrada 
undersample_with_resample = pd.concat([not_fraud_undersampled, fraud])

X_train_undersample_with_resample = undersample_with_resample.drop('isFraud',axis = 1)
y_train_undersample_with_resample = undersample_with_resample['isFraud'].astype('uint8')

#X_train_undersample_with_resample = undersample_with_resample.drop('Class',axis = 1)
#y_train_undersample_with_resample = undersample_with_resample['Class'].astype('uint8')

# contando as classes minoritária e majoritária
undersample_with_resample.isFraud.value_counts()
#undersample_with_resample.Class.value_counts()
# Out:
# Wall time: 204 ms
# isFraud
# 0    16530
# 1    16530
# Name: count, dtype: int64

# %% [markdown]
# ### Undersample com Random Undersampling (RUS)

# %%
# %%time

import imblearn
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=0)

X_train_undersample_with_rus, y_train_undersample_with_rus = rus.fit_resample(X_train, y_train)

# combinando as classes minoritária com a majoritária subamostrada 
undersample_with_rus = pd.concat([X_train_undersample_with_rus, y_train_undersample_with_rus], axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
undersample_with_rus.isFraud.value_counts()
#undersample_with_rus.Class.value_counts()
# Out:
# Wall time: 831 ms
# isFraud
# 0    16530
# 1    16530
# Name: count, dtype: int64

# %% [markdown]
# ### Undersample com Near Miss

# %%
# %%time

from imblearn.under_sampling import NearMiss

nm = NearMiss()

X_train_undersample_with_near_miss, y_train_undersample_with_near_miss = nm.fit_resample(X_train, y_train)

# combinando as classes minoritária com a majoritária subamostrada
undersample_with_near_miss = pd.concat([X_train_undersample_with_near_miss, y_train_undersample_with_near_miss], \
                                       axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
undersample_with_near_miss.isFraud.value_counts()
#undersample_with_near_miss.Class.value_counts()
# Out:
# Wall time: 20.5 s
# isFraud
# 0    16530
# 1    16530
# Name: count, dtype: int64

# %% [markdown]
# ### Undersample com Instance Hardness Threshold

# %%
# %%time

from imblearn.under_sampling import InstanceHardnessThreshold

iht = InstanceHardnessThreshold(random_state=0)

X_train_undersample_with_iht, y_train_undersample_with_iht = iht.fit_resample(X_train, y_train)

# combinando as classes minoritária com a majoritária subamostrada
undersample_with_iht = pd.concat([X_train_undersample_with_iht, \
                                        y_train_undersample_with_iht], \
                                       axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
undersample_with_iht.isFraud.value_counts()
#undersample_with_iht.Class.value_counts()
# Out:
# Wall time: 12min 7s
# isFraud
# 0    202189
# 1     16530
# Name: count, dtype: int64

# %% [markdown]
# ### Oversample com Resample

# %%
# %%time

fraud_upsampled = resample(fraud, 
                           replace = True, # sample with replacement
                           n_samples = len(not_fraud), # match number in majority class
                           random_state = 27)

# combinando as classes majoritária com a minoritária sobreamostrada 
oversample_with_resample = pd.concat([not_fraud, fraud_upsampled])

X_train_oversample_with_resample = oversample_with_resample.drop('isFraud',axis = 1)
y_train_oversample_with_resample = oversample_with_resample['isFraud'].astype('uint8')

#X_train_oversample_with_resample = oversample_with_resample.drop('Class',axis = 1)
#y_train_oversample_with_resample = oversample_with_resample['Class'].astype('uint8')

# contando as classes minoritária e majoritária
oversample_with_resample.isFraud.value_counts()
#oversample_with_resample.Class.value_counts()
# Out:
# Wall time: 507 ms
# isFraud
# 0    455902
# 1    455902
# Name: count, dtype: int64

# %% [markdown]
# ### Oversample com Random Oversampling (ROS)

# %%
# %%time

from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)

X_train_oversample_with_ros, y_train_oversample_with_ros = ros.fit_resample(X_train, y_train)

# combinando as classes majoritária com a minoritária sobreamostrada 
oversample_with_ros = pd.concat([X_train_oversample_with_ros, y_train_oversample_with_ros], axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
oversample_with_ros.isFraud.value_counts()
#oversample_with_ros.Class.value_counts()
# Out:
# Wall time: 6.21 s
# isFraud
# 0    455902
# 1    455902
# Name: count, dtype: int64

# %% [markdown]
# ### Oversampling com SMOTE

# %%
# %%time

from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_oversample_with_smote, y_train_oversample_with_smote = smote.fit_resample(X_train, y_train)

# combinando as classes majoritária com a minoritária sobreamostrada 
train_oversample_with_smote = pd.concat([X_train_oversample_with_smote, y_train_oversample_with_smote], \
                                        axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
train_oversample_with_smote.isFraud.value_counts()
#train_oversample_with_smote.Class.value_counts()
# Out:
# Wall time: 6.31 s
# isFraud
# 0    455902
# 1    455902
# Name: count, dtype: int64

# %% [markdown]
# ### Oversample com Borderline SMOTE

# %%
# %%time

from imblearn.over_sampling import BorderlineSMOTE

smote = BorderlineSMOTE(random_state=42)

X_train_oversample_with_borderline_smote, y_train_oversample_with_borderline_smote = smote.fit_resample(X_train, y_train)

# combinando as classes majoritária com a minoritária sobreamostrada 
oversample_with_borderline_smote = pd.concat([X_train_oversample_with_borderline_smote, \
                                   y_train_oversample_with_borderline_smote], axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
oversample_with_borderline_smote.isFraud.value_counts()
#oversample_with_borderline_smote.Class.value_counts()
# Out:
# Wall time: 27.6 s
# isFraud
# 0    455902
# 1    455902
# Name: count, dtype: int64

# %% [markdown]
# ### Oversampling com AdaSyn

# %%
# %%time

from imblearn.over_sampling import ADASYN

adasyn = ADASYN(random_state=42)

X_train_oversample_with_adasyn, y_train_oversample_with_adasyn = adasyn.fit_resample(X_train, y_train)

# combinando as classes majoritária com a minoritária sobreamostrada 
train_oversample_with_adasyn = pd.concat([X_train_oversample_with_adasyn, \
                                                    y_train_oversample_with_adasyn], \
                                        axis = 1, ignore_index=False)

# contando as classes minoritária e majoritária
train_oversample_with_adasyn.isFraud.value_counts()
#train_oversample_with_adasyn.Class.value_counts()
# Out:
# Wall time: 27.4 s
# isFraud
# 1    456567
# 0    455902
# Name: count, dtype: int64

# %%
t1 = time.time()
print("Script took {:.2} s".format(t1 - t0))
# Out:
# Script took 9.9e+02 s

# %% [markdown]
# # Redução de Dimensionalidade

# %%
# importando as bibliotecas necessárias
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %% [markdown]
# ## Sem Balanceamento

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train, y_train)
X_train_100_chi2 = new_100_chi2.transform(X_train)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train.iloc[:, cols]

cols_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Undersample com Resample

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_undersample_with_resample, y_train_undersample_with_resample)
X_train_oversample_with_smote_100_chi2 = new_100_chi2.transform(X_train_undersample_with_resample)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_undersample_with_resample.iloc[:, cols]

undersample_with_resample_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Undersample com Random Undersampling (RUS)

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_undersample_with_rus, y_train_undersample_with_rus)
X_train_undersample_with_rus_100_chi2 = new_100_chi2.transform(X_train_undersample_with_rus)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_undersample_with_rus.iloc[:, cols]

undersample_with_rus_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Undersample com Near Miss

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_undersample_with_near_miss, y_train_undersample_with_near_miss)
X_train_undersample_with_near_miss_100_chi2 = new_100_chi2.transform(X_train_undersample_with_near_miss)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_undersample_with_near_miss.iloc[:, cols]

undersample_with_near_miss_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Undersample com Instance Hardness Threshold

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_undersample_with_iht, y_train_undersample_with_iht)
X_train_undersample_with_iht_100_chi2 = new_100_chi2.transform(X_train_undersample_with_iht)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_undersample_with_iht.iloc[:, cols]

undersample_with_iht_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Oversample com Resample

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_oversample_with_resample, y_train_oversample_with_resample)
X_train_oversample_with_resample_100_chi2 = new_100_chi2.transform(X_train_oversample_with_resample)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_oversample_with_resample.iloc[:, cols]

oversample_with_resample_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Oversample com Random Oversampling (ROS)

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_oversample_with_ros, y_train_oversample_with_ros)
X_train_oversample_with_ros_100_chi2 = new_100_chi2.transform(X_train_oversample_with_ros)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_oversample_with_ros.iloc[:, cols]

oversample_with_ros_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Oversampling com SMOTE

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_oversample_with_smote, y_train_oversample_with_smote)
X_train_oversample_with_smote_100_chi2 = new_100_chi2.transform(X_train_oversample_with_smote)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_oversample_with_smote.iloc[:, cols]

oversample_with_smote_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Oversample com Borderline SMOTE

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_oversample_with_borderline_smote, y_train_oversample_with_borderline_smote)
X_train_oversample_with_borderline_smote_100_chi2 = new_100_chi2.transform(X_train_oversample_with_borderline_smote)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_oversample_with_borderline_smote.iloc[:, cols]

oversample_with_borderline_smote_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# ## Oversampling com AdaSyn

# %%
# selecionando os 100 melhores atributos para explicar o comportamento da variágel target ('y_train') 
model_100_chi2 = SelectKBest(chi2, k = 100)
new_100_chi2 = model_100_chi2.fit(X_train_oversample_with_adasyn, y_train_oversample_with_adasyn)
X_train_oversample_with_adasyn_100_chi2 = new_100_chi2.transform(X_train_oversample_with_adasyn)

# transformando os atributos selecionados em dataframe 
cols = new_100_chi2.get_support(indices = True)
features_df_new_100_chi2 = X_train_oversample_with_adasyn.iloc[:, cols]

oversample_with_adasyn_100_chi2 = features_df_new_100_chi2.columns

# %% [markdown]
# # Seleção do Modelo de Classificação

# %% [markdown]
# ## Inicializando os classificadores

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import cross_validate

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
clf_et = ExtraTreesClassifier(n_estimators=100)#, random_state=0)
clf_dt = DecisionTreeClassifier()#random_state=0)

# %% [markdown]
# ## Sem Balanceamento Nem Limiares

# %% [markdown]
# ### Top 100 Qui-Quadrado

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_100_chi2, y_train)

# Faça previsões no conjunto de teste
previsoes = clf_et.predict(X_test[cols_100_chi2])

# Calcule o F1-Score positivo para o conjunto de treino
f1_score_positivo_teste = f1_score(y_test, previsoes, pos_label = 1)

f1_score_positivo_teste
# Out:
# Wall time: 2min 28s
# 0.648751788837653

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_100_chi2, y_train)

# Faça previsões no conjunto de teste
previsoes = clf_dt.predict(X_test[cols_100_chi2])

# Calcule o F1-Score positivo para o conjunto de treino
f1_score_positivo_teste = f1_score(y_test, previsoes, pos_label = 1)

f1_score_positivo_teste
# Out:
# Wall time: 23.1 s
# 0.5428803527909944

# %% [markdown]
# ### Todos os atributos

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train, y_train)

# Faça previsões no conjunto de teste
previsoes = clf_dt.predict(X_test)

# Calcule o F1-Score positivo para o conjunto de treino
f1_score_positivo_teste = f1_score(y_test, previsoes, pos_label = 1)

f1_score_positivo_teste
# Out:
# Wall time: 31.7 s
# 0.5518600069532971

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_100_chi2, y_train)

# Faça previsões no conjunto de teste
previsoes = clf_dt.predict(X_test[cols_100_chi2])

# Calcule o F1-Score positivo para o conjunto de treino
f1_score_positivo_teste = f1_score(y_test, previsoes, pos_label = 1)

f1_score_positivo_teste
# Out:
# Wall time: 22.6 s
# 0.5347085409665083

# %% [markdown]
# ## Validação Cruzada para Diferentes Limiares

# %% [markdown]
# ### Top 100 Qui-Quadrado

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_100_chi2, y_train)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[cols_100_chi2].iloc[test_index], X_test[cols_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 3min 39s
#           Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.33559363691253963]                   NaN                   NaN
# 1                     NaN  [0.5413836633192793]                   NaN
# 2                     NaN                   NaN  [0.6506340452121485]
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# 5                     NaN                   NaN                   NaN
# 6                     NaN                   NaN                   NaN
# 7                     NaN                   NaN                   NaN
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# 13                    NaN                   NaN                   NaN
# 14                    NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.7057314316203926]                   NaN                   NaN
# 4                    NaN  [0.7289068312132452]                   NaN
# 5                    NaN                   NaN  [0.7266455054655548]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.7148942796188716]                   NaN                   NaN
# 7                    NaN  [0.6972111420036853]                   NaN
# 8                    NaN                   NaN  [0.6759287861798778]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.6534229175615902]                   NaN                   NaN
# 10                   NaN  [0.6255444013220995]                   NaN
# 11                   NaN                   NaN  [0.5960142434616492]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7        Threshold: 0.75
# 0                    NaN                   NaN                    NaN
# 1                    NaN                   NaN                    NaN
# 2                    NaN                   NaN                    NaN
# 3                    NaN                   NaN                    NaN
# 4                    NaN                   NaN                    NaN
# 5                    NaN                   NaN                    NaN
# 6                    NaN                   NaN                    NaN
# 7                    NaN                   NaN                    NaN
# 8                    NaN                   NaN                    NaN
# 9                    NaN                   NaN                    NaN
# 10                   NaN                   NaN                    NaN
# 11                   NaN                   NaN                    NaN
# 12  [0.5594371285104582]                   NaN                    NaN
# 13                   NaN  [0.5199374337899951]                    NaN
# 14                   NaN                   NaN  [0.47236806466760006]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_100_chi2, y_train)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[cols_100_chi2].iloc[test_index], X_test[cols_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 35.6 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.5428190497904958]                   NaN                   NaN
# 1                    NaN  [0.5428190497904958]                   NaN
# 2                    NaN                   NaN  [0.5428190497904958]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.5428190497904958]                   NaN                   NaN
# 4                    NaN  [0.5428190497904958]                   NaN
# 5                    NaN                   NaN  [0.5428190497904958]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.5428190497904958]                   NaN                   NaN
# 7                    NaN  [0.5428190497904958]                   NaN
# 8                    NaN                   NaN  [0.5428190497904958]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.5428190497904958]                   NaN                   NaN
# 10                   NaN  [0.5428804230164259]                   NaN
# 11                   NaN                   NaN  [0.5428804230164259]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5428804230164259]                   NaN                   NaN
# 13                   NaN  [0.5428804230164259]                   NaN
# 14                   NaN                   NaN  [0.5428804230164259]

# %% [markdown]
# ### Todos os atributos

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train, y_train)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 4min 5s
#           Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.34088369452106415]                   NaN                   NaN
# 1                     NaN  [0.5424932190677928]                   NaN
# 2                     NaN                   NaN  [0.6516931188643281]
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# 5                     NaN                   NaN                   NaN
# 6                     NaN                   NaN                   NaN
# 7                     NaN                   NaN                   NaN
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# 13                    NaN                   NaN                   NaN
# 14                    NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.7100798735091308]                   NaN                   NaN
# 4                    NaN  [0.7318934034415377]                   NaN
# 5                    NaN                   NaN  [0.7336687710890435]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4      Threshold: 0.45  \
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   NaN                  NaN
# 3                    NaN                   NaN                  NaN
# 4                    NaN                   NaN                  NaN
# 5                    NaN                   NaN                  NaN
# 6   [0.7231054866748097]                   NaN                  NaN
# 7                    NaN  [0.7018987295563317]                  NaN
# 8                    NaN                   NaN  [0.680045436115476]
# 9                    NaN                   NaN                  NaN
# 10                   NaN                   NaN                  NaN
# 11                   NaN                   NaN                  NaN
# 12                   NaN                   NaN                  NaN
# 13                   NaN                   NaN                  NaN
# 14                   NaN                   NaN                  NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.6523845449712751]                   NaN                   NaN
# 10                   NaN  [0.6248019080123429]                   NaN
# 11                   NaN                   NaN  [0.5928403646971201]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5577609759462752]                   NaN                   NaN
# 13                   NaN  [0.5126735484632714]                   NaN
# 14                   NaN                   NaN  [0.4682381861392494]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train, y_train)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 39.3 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.5481205473445991]                   NaN                   NaN
# 1                    NaN  [0.5481205473445991]                   NaN
# 2                    NaN                   NaN  [0.5481205473445991]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.5481205473445991]                   NaN                   NaN
# 4                    NaN  [0.5481205473445991]                   NaN
# 5                    NaN                   NaN  [0.5481205473445991]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.5481205473445991]                   NaN                   NaN
# 7                    NaN  [0.5481205473445991]                   NaN
# 8                    NaN                   NaN  [0.5481205473445991]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.5481205473445991]                   NaN                   NaN
# 10                   NaN  [0.5481782018857951]                   NaN
# 11                   NaN                   NaN  [0.5481782018857951]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5481782018857951]                   NaN                   NaN
# 13                   NaN  [0.5481782018857951]                   NaN
# 14                   NaN                   NaN  [0.5481782018857951]

# %% [markdown]
# ## Validação Cruzada para Undersampling com Resample

# %%
clf_et = ExtraTreesClassifier(n_estimators=100)#, random_state=0)
clf_dt = DecisionTreeClassifier()#random_state=0)

# %% [markdown]
# ### Top 100 Qui-Quadrado

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_undersample_with_resample[undersample_with_resample_100_chi2], y_train_undersample_with_resample)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[undersample_with_resample_100_chi2].iloc[test_index], X_test[undersample_with_resample_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 1min 7s
#           Threshold: 0.05         Threshold: 0.1       Threshold: 0.15  \
# 0   [0.07342783674931128]                    NaN                   NaN
# 1                     NaN  [0.08652304984490089]                   NaN
# 2                     NaN                    NaN  [0.1035202518696774]
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9                     NaN                    NaN                   NaN
# 10                    NaN                    NaN                   NaN
# 11                    NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#            Threshold: 0.2        Threshold: 0.25         Threshold: 0.3  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3   [0.12349922160053453]                    NaN                    NaN
# 4                     NaN  [0.14718815518045383]                    NaN
# 5                     NaN                    NaN  [0.17510971886042453]
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#           Threshold: 0.35         Threshold: 0.4       Threshold: 0.45  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6   [0.20681459735349383]                    NaN                   NaN
# 7                     NaN  [0.24235217915166096]                   NaN
# 8                     NaN                    NaN  [0.2826354001513796]
# 9                     NaN                    NaN                   NaN
# 10                    NaN                    NaN                   NaN
# 11                    NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#           Threshold: 0.5        Threshold: 0.55         Threshold: 0.6  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
# 5                    NaN                    NaN                    NaN
# 6                    NaN                    NaN                    NaN
# 7                    NaN                    NaN                    NaN
# 8                    NaN                    NaN                    NaN
# 9   [0.3268787022556119]                    NaN                    NaN
# 10                   NaN  [0.37820251266801724]                    NaN
# 11                   NaN                    NaN  [0.43284732605539544]
# 12                   NaN                    NaN                    NaN
# 13                   NaN                    NaN                    NaN
# 14                   NaN                    NaN                    NaN
#
#           Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# 5                     NaN                   NaN                   NaN
# 6                     NaN                   NaN                   NaN
# 7                     NaN                   NaN                   NaN
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12  [0.48913520384206166]                   NaN                   NaN
# 13                    NaN  [0.5400914528235743]                   NaN
# 14                    NaN                   NaN  [0.5861041512189468]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_undersample_with_resample[undersample_with_resample_100_chi2], y_train_undersample_with_resample)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[undersample_with_resample_100_chi2].iloc[test_index], X_test[undersample_with_resample_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 13.5 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.1895960474124245]                   NaN                   NaN
# 1                    NaN  [0.1895960474124245]                   NaN
# 2                    NaN                   NaN  [0.1895960474124245]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.1895960474124245]                   NaN                   NaN
# 4                    NaN  [0.1895960474124245]                   NaN
# 5                    NaN                   NaN  [0.1895960474124245]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.1895960474124245]                   NaN                   NaN
# 7                    NaN  [0.1895960474124245]                   NaN
# 8                    NaN                   NaN  [0.1895960474124245]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.1895960474124245]                   NaN                   NaN
# 10                   NaN  [0.1896233274688705]                   NaN
# 11                   NaN                   NaN  [0.1896233274688705]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.1896233274688705]                   NaN                   NaN
# 13                   NaN  [0.1896233274688705]                   NaN
# 14                   NaN                   NaN  [0.1896233274688705]

# %% [markdown]
# ### Todos os atributos

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_undersample_with
# 3                   NaN                    NaN                    NaN
# 4                   NaN                    NaN                    NaN
# 5                   NaN                    NaN                    NaN
# 6                   NaN                    NaN                    NaN
# 7                   NaN                    NaN                    NaN
# 8                   NaN                    NaN                    NaN
# 9                   NaN                    NaN                    NaN
# 10                  NaN                    NaN                    NaN
# 11                  NaN                    NaN                    NaN
# 12                  NaN                    NaN                    NaN
# 13                  NaN                    NaN                    NaN
# 14                  NaN                    NaN                    NaN
#
#            Threshold: 0.2        Threshold: 0.25         Threshold: 0.3  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3   [0.06916120869187563]                    NaN                    NaN
# 4                     NaN  [0.06935608084386348]                    NaN
# 5                     NaN                    NaN  [0.06944904605347588]
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#           Threshold: 0.35         Threshold: 0.4        Threshold: 0.45  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6   [0.06957841506451654]                    NaN                    NaN
# 7                     NaN  [0.06960283306062112]                    NaN
# 8                     NaN                    NaN  [0.06982359218234206]
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#            Threshold: 0.5        Threshold: 0.55         Threshold: 0.6  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9   [0.07008584443903502]                    NaN                    NaN
# 10                    NaN  [0.07046304576936248]                    NaN
# 11                    NaN                    NaN  [0.07064858226049632]
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#           Threshold: 0.65        Threshold: 0.7        Threshold: 0.75
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
# 5                     NaN                   NaN                    NaN
# 6                     NaN                   NaN                    NaN
# 7                     NaN                   NaN                    NaN
# 8                     NaN                   NaN                    NaN
# 9                     NaN                   NaN                    NaN
# 10                    NaN                   NaN                    NaN
# 11                    NaN                   NaN                    NaN
# 12  [0.07066886639157036]                   NaN                    NaN
# 13                    NaN  [0.0708937215190601]                    NaN
# 14                    NaN                   NaN  [0.07122531700040471]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_undersample_with_near_miss[undersample_with_near_miss_100_chi2], y_train_undersample_with_near_miss)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[undersample_with_near_miss_100_chi2].iloc[test_index], X_test[undersample_with_near_miss_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 12.7 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.0698378919930119]                   NaN                   NaN
# 1                    NaN  [0.0698378919930119]                   NaN
# 2                    NaN                   NaN  [0.0698378919930119]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.0698378919930119]                   NaN                   NaN
# 4                    NaN  [0.0698378919930119]                   NaN
# 5                    NaN                   NaN  [0.0698378919930119]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.0698378919930119]                   NaN                   NaN
# 7                    NaN  [0.0698378919930119]                   NaN
# 8                    NaN                   NaN  [0.0698378919930119]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5        Threshold: 0.55         Threshold: 0.6  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
# 5                    NaN                    NaN                    NaN
# 6                    NaN                    NaN                    NaN
# 7                    NaN                    NaN                    NaN
# 8                    NaN                    NaN                    NaN
# 9   [0.0698378919930119]                    NaN                    NaN
# 10                   NaN  [0.06983850812522419]                    NaN
# 11                   NaN                    NaN  [0.06983850812522419]
# 12                   NaN                    NaN                    NaN
# 13                   NaN                    NaN                    NaN
# 14                   NaN                    NaN                    NaN
#
#           Threshold: 0.65         Threshold: 0.7        Threshold: 0.75
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12  [0.06983850812522419]                    NaN                    NaN
# 13                    NaN  [0.06983850812522419]                    NaN
# 14                    NaN                    NaN  [0.06983850812522419]

# %% [markdown]
# ### Todos os atributos

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_undersample_with_near_miss, y_train_undersample_with_near_miss)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 41.2 s
#           Threshold: 0.05         Threshold: 0.1       Threshold: 0.15  \
# 0   [0.06881378382004992]                    NaN                   NaN
# 1                     NaN  [0.06899027689946251]                   NaN
# 2                     NaN                    NaN  [0.0691279091591596]
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9                     NaN                    NaN                   NaN
# 10                    NaN                    NaN                   NaN
# 11                    NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#            Threshold: 0.2        Threshold: 0.25        Threshold: 0.3  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3   [0.06932300760556244]                    NaN                   NaN
# 4                     NaN  [0.06947945130192991]                   NaN
# 5                     NaN                    NaN  [0.0695990099714984]
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9                     NaN                    NaN                   NaN
# 10                    NaN                    NaN                   NaN
# 11                    NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#           Threshold: 0.35         Threshold: 0.4        Threshold: 0.45  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6   [0.06981590924612088]                    NaN                    NaN
# 7                     NaN  [0.06999278274579332]                    NaN
# 8                     NaN                    NaN  [0.07011951238731366]
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#            Threshold: 0.5        Threshold: 0.55        Threshold: 0.6  \
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9   [0.07042670974436073]                    NaN                   NaN
# 10                    NaN  [0.07060646655304728]                   NaN
# 11                    NaN                    NaN  [0.0708535972843378]
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#           Threshold: 0.65        Threshold: 0.7        Threshold: 0.75
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   NaN                    NaN
# 4                     NaN                   NaN                    NaN
# 5                     NaN                   NaN                    NaN
# 6                     NaN                   NaN                    NaN
# 7                     NaN                   NaN                    NaN
# 8                     NaN                   NaN                    NaN
# 9                     NaN                   NaN                    NaN
# 10                    NaN                   NaN                    NaN
# 11                    NaN                   NaN                    NaN
# 12  [0.07111131135166138]                   NaN                    NaN
# 13                    NaN  [0.0711319087115578]                    NaN
# 14                    NaN                   NaN  [0.07128660016487973]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_undersample_with_near_miss, y_train_undersample_with_near_miss)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 8.8 s
#           Threshold: 0.05         Threshold: 0.1        Threshold: 0.15  \
# 0   [0
_with_resample)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[oversample_with_resample_100_chi2].iloc[test_index], X_test[oversample_with_resample_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 47.5 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.5389042171921232]                   NaN                   NaN
# 1                    NaN  [0.5389042171921232]                   NaN
# 2                    NaN                   NaN  [0.5389042171921232]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.5389042171921232]                   NaN                   NaN
# 4                    NaN  [0.5389042171921232]                   NaN
# 5                    NaN                   NaN  [0.5389042171921232]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.5389042171921232]                   NaN                   NaN
# 7                    NaN  [0.5389042171921232]                   NaN
# 8                    NaN                   NaN  [0.5389042171921232]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.5389042171921232]                   NaN                   NaN
# 10                   NaN  [0.5389042171921232]                   NaN
# 11                   NaN                   NaN  [0.5389042171921232]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5389042171921232]                   NaN                   NaN
# 13                   NaN  [0.5389042171921232]                   NaN
# 14                   NaN                   NaN  [0.5389042171921232]

# %% [markdown]
# ### Todas as colunas

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_oversample_with_resample, y_train_oversample_with_resample)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 7min 2s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.3634069949292371]                   NaN                   NaN
# 1                    NaN  [0.5642478399260077]                   NaN
# 2                    NaN                   NaN  [0.6674782293358905]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.7141022044124198]                   NaN                   NaN
# 4                    NaN  [0.7304360548283533]                   NaN
# 5                    NaN                   NaN  [0.7280801360315721]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.7166951926981456]                   NaN                   NaN
# 7                    NaN  [0.6951418460537455]                   NaN
# 8                    NaN                   NaN  [0.6730976358305376]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5      Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 3                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
# 5                    NaN                  NaN                   NaN
# 6                    NaN                  NaN                   NaN
# 7                    NaN                  NaN                   NaN
# 8                    NaN                  NaN                   NaN
# 9   [0.6459229598324496]                  NaN                   NaN
# 10                   NaN  [0.611597791548534]                   NaN
# 11                   NaN                  NaN  [0.5765838056077971]
# 12                   NaN                  NaN                   NaN
# 13                   NaN                  NaN                   NaN
# 14                   NaN                  NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5391508914025428]                   NaN                   NaN
# 13                   NaN  [0.4944893121201234]                   NaN
# 14                   NaN                   NaN  [0.4446845638658776]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_oversample_with_resample, y_train_oversample_with_resample)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 54 s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.5384154838838555]                   NaN                   NaN
# 1                    NaN  [0.5384154838838555]                   NaN
# 2                    NaN                   NaN  [0.5384154838838555]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.5384154838838555]                   NaN                   NaN
# 4                    NaN  [0.5384154838838555]                   NaN
# 5                    NaN                   NaN  [0.5384154838838555]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.5384154838838555]                   NaN                   NaN
# 7                    NaN  [0.5384154838838555]                   NaN
# 8                    NaN                   NaN  [0.5384154838838555]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.5384154838838555]                   NaN                   NaN
# 10                   NaN  [0.5384154838838555]                   NaN
# 11                   NaN                   NaN  [0.5384154838838555]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5384154838838555]                   NaN                   NaN
# 13                   NaN  [0.5384154838838555]                   NaN
# 14                   NaN                   NaN  [0.5384154838838555]

# %% [markdown]
# ## Validação Cruzada para Oversampling com Random OverSampling (ROS)

# %%
clf_et = ExtraTreesClassifier(n_estimators=100)#, random_state=0)
clf_dt = DecisionTreeClassifier()#random_state=0)

# %% [markdown]
# ### Top 100 Qui-Quadrado

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_oversample_with_ros[oversample_with_ros_100_chi2], y_train_oversample_with_ros)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[oversample_with_ros_100_chi2].iloc[test_index], X_test[oversample_with_ros_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 6min 14s
#           Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.35950881811130414]                   NaN                   NaN
# 1                     NaN  [0.5662691519913763]                   NaN
# 2                     NaN                   NaN  [0.6719159116042663]
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
# 5                     NaN                   NaN                   NaN
# 6                     NaN                   NaN                   NaN
# 7                     NaN                   NaN                   NaN
# 8                     NaN                   NaN                   NaN
# 9                     NaN                   NaN                   NaN
# 10                    NaN                   NaN                   NaN
# 11                    NaN                   NaN                   NaN
# 12                    NaN                   NaN                   NaN
# 13                    NaN                   NaN                   NaN
# 14                    NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25       Threshold: 0.3  \
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   Na

# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5838204081707108]                   NaN                   NaN
# 13                   NaN  [0.5453787574376749]                   NaN
# 14                   NaN                   NaN  [0.5036095565500849]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_oversample_with_borderline_smote, y_train_oversample_with_borderline_smote)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 1min 11s
#           Threshold: 0.05         Threshold: 0.1        Threshold: 0.15  \
# 0   [0.46716595891024654]                    NaN                    NaN
# 1                     NaN  [0.46716595891024654]                    NaN
# 2                     NaN                    NaN  [0.46716595891024654]
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#            Threshold: 0.2        Threshold: 0.25         Threshold: 0.3  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3   [0.46716595891024654]                    NaN                    NaN
# 4                     NaN  [0.46716595891024654]                    NaN
# 5                     NaN                    NaN  [0.46716595891024654]
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#           Threshold: 0.35         Threshold: 0.4        Threshold: 0.45  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6   [0.46716595891024654]                    NaN                    NaN
# 7                     NaN  [0.46716595891024654]                    NaN
# 8                     NaN                    NaN  [0.46716595891024654]
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#            Threshold: 0.5        Threshold: 0.55         Threshold: 0.6  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9   [0.46716595891024654]                    NaN                    NaN
# 10                    NaN  [0.46716595891024654]                    NaN
# 11                    NaN                    NaN  [0.46716595891024654]
# 12                    NaN                    NaN                    NaN
# 13                    NaN                    NaN                    NaN
# 14                    NaN                    NaN                    NaN
#
#           Threshold: 0.65         Threshold: 0.7        Threshold: 0.75
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
# 5                     NaN                    NaN                    NaN
# 6                     NaN                    NaN                    NaN
# 7                     NaN                    NaN                    NaN
# 8                     NaN                    NaN                    NaN
# 9                     NaN                    NaN                    NaN
# 10                    NaN                    NaN                    NaN
# 11                    NaN                    NaN                    NaN
# 12  [0.46716595891024654]                    NaN                    NaN
# 13                    NaN  [0.46716595891024654]                    NaN
# 14                    NaN                    NaN  [0.46716595891024654]

# %% [markdown]
# ## Validação Cruzada para Oversample com AdaSyn

# %%
clf_et = ExtraTreesClassifier(n_estimators=100)#, random_state=0)
clf_dt = DecisionTreeClassifier()#random_state=0)

# %% [markdown]
# ### Top 100 Qui-Quadrado

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_et.fit(X_train_oversample_with_adasyn[oversample_with_adasyn_100_chi2], y_train_oversample_with_adasyn)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test[oversample_with_adasyn_100_chi2].iloc[test_index], X_test[oversample_with_adasyn_100_chi2].iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_et.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 5min 23s
#           Threshold: 0.05         Threshold: 0.1       Threshold: 0.15  \
# 0   [0.26465640564785453]                    NaN                   NaN
# 1                     NaN  [0.43355536725336236]                   NaN
# 2                     NaN                    NaN  [0.5505391194161791]
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9                     NaN                    NaN                   NaN
# 10                    NaN                    NaN                   NaN
# 11                    NaN                    NaN                   NaN
# 12                    NaN                    NaN                   NaN
# 13                    NaN                    NaN                   NaN
# 14                    NaN                    NaN                   NaN
#
#          Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3   [0.626944715451968]                   NaN                   NaN
# 4                   NaN  [0.6730588243471078]                   NaN
# 5                   NaN                   NaN  [0.6966965063508671]
# 6                   NaN                   NaN                   NaN
# 7                   NaN                   NaN                   NaN
# 8                   NaN                   NaN                   NaN
# 9                   NaN                   NaN                   NaN
# 10                  NaN                   NaN                   NaN
# 11                  NaN                   NaN                   NaN
# 12                  NaN                   NaN                   NaN
# 13                  NaN                   NaN                   NaN
# 14                  NaN                   NaN                   NaN
#
#          Threshold: 0.35       Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                  NaN                   NaN
# 1                    NaN                  NaN                   NaN
# 2                    NaN                  NaN                   NaN
# 3                    NaN                  NaN                   NaN
# 4                    NaN                  NaN                   NaN
# 5                    NaN                  NaN                   NaN
# 6   [0.7058703501182982]                  NaN                   NaN
# 7                    NaN  [0.706931162122866]                   NaN
# 8                    NaN                  NaN  [0.6954569793058057]
# 9                    NaN                  NaN                   NaN
# 10                   NaN                  NaN                   NaN
# 11                   NaN                  NaN                   NaN
# 12                   NaN                  NaN                   NaN
# 13                   NaN                  NaN                   NaN
# 14                   NaN                  NaN                   NaN
#
#          Threshold: 0.5       Threshold: 0.55       Threshold: 0.6  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN                  NaN
# 4                   NaN                   NaN                  NaN
# 5                   NaN                   NaN                  NaN
# 6                   NaN                   NaN                  NaN
# 7                   NaN                   NaN                  NaN
# 8                   NaN                   NaN                  NaN
# 9   [0.680651528364869]                   NaN                  NaN
# 10                  NaN  [0.6541746588260553]                  NaN
# 11                  NaN                   NaN  [0.633608215604899]
# 12                  NaN                   NaN                  NaN
# 13                  NaN                   NaN                  NaN
# 14                  NaN                   NaN                  NaN
#
#          Threshold: 0.65        Threshold: 0.7      Threshold: 0.75
# 0                    NaN                   NaN                  NaN
# 1                    NaN                   NaN                  NaN
# 2                    NaN                   NaN                  NaN
# 3                    NaN                   NaN                  NaN
# 
threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
# 5                   NaN                   NaN                   NaN
# 6                   NaN                   NaN                   NaN
# 7                   NaN                   NaN                   NaN
# 8                   NaN                   NaN                   NaN
# 9   [0.684698680463541]                   NaN                   NaN
# 10                  NaN  [0.6625468943854718]                   NaN
# 11                  NaN                   NaN  [0.6318728123087849]
# 12                  NaN                   NaN                   NaN
# 13                  NaN                   NaN                   NaN
# 14                  NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.6024607848908337]                   NaN                   NaN
# 13                   NaN  [0.5641761886622572]                   NaN
# 14                   NaN                   NaN  [0.5194437604088877]

# %%
# %%time

# Crie e ajuste o classificador ao conjunto de treinamento (substitua pelo classificador desejado)
clf_dt.fit(X_train_oversample_with_adasyn, y_train_oversample_with_adasyn)

# Especificando o número de folds para a validação cruzada (10 é comum)
num_folds = 10

# Criando um objeto StratifiedKFold para garantir estratificação nos folds
stratified_kfold = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# Inicializar uma lista para armazenar os resultados
adj_threshold = []

# criar lista de limiares
thresholds = [ j/20 for j in range(1,16)]

# Iterar sobre os limiares
for i in thresholds:

    # Inicializar uma lista para armazenar as métricas de cada fold
    metrics_per_threshold = []

    # Iterar sobre as dobras
    for test_index, val_index in stratified_kfold.split(X_test, y_test):
        X_val, X_val_2 = X_test.iloc[test_index], X_test.iloc[val_index]
        y_val, y_val_2 = y_test.iloc[test_index], y_test.iloc[val_index]

        y_pred_new_threshold = (clf_dt.predict_proba(X_val_2)[:,1]>=i).astype(int)
        
        #calculating the threshold with respect to class 1
        f1_score_positivo_adj_threshold =  f1_score(y_val_2, y_pred_new_threshold, pos_label = 1, average='binary')
        metrics_adj_threshold = [f1_score_positivo_adj_threshold]

        metrics_per_threshold.append(metrics_adj_threshold)
        
    # Calcular a média das métricas para todos os folds
    avg_metrics_per_threshold = np.mean(metrics_per_threshold, axis=0)
    
    # Armazenar os resultados
    name = 'Threshold: ' + str(i) 
    adj_threshold.append({name: avg_metrics_per_threshold})

# Criar um DataFrame a partir dos resultados
df_results = pd.DataFrame(adj_threshold)
df_results
# Out:
# Wall time: 1min 5s
#          Threshold: 0.05        Threshold: 0.1       Threshold: 0.15  \
# 0   [0.5025724245676194]                   NaN                   NaN
# 1                    NaN  [0.5025724245676194]                   NaN
# 2                    NaN                   NaN  [0.5025724245676194]
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.2       Threshold: 0.25        Threshold: 0.3  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3   [0.5025724245676194]                   NaN                   NaN
# 4                    NaN  [0.5025724245676194]                   NaN
# 5                    NaN                   NaN  [0.5025724245676194]
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.35        Threshold: 0.4       Threshold: 0.45  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6   [0.5025724245676194]                   NaN                   NaN
# 7                    NaN  [0.5025724245676194]                   NaN
# 8                    NaN                   NaN  [0.5025724245676194]
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#           Threshold: 0.5       Threshold: 0.55        Threshold: 0.6  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9   [0.5025724245676194]                   NaN                   NaN
# 10                   NaN  [0.5026300281112305]                   NaN
# 11                   NaN                   NaN  [0.5026300281112305]
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
#
#          Threshold: 0.65        Threshold: 0.7       Threshold: 0.75
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9                    NaN                   NaN                   NaN
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12  [0.5026300281112305]                   NaN                   NaN
# 13                   NaN  [0.5026300281112305]                   NaN
# 14                   NaN                   NaN  [0.5026300281112305]

# %% [markdown]
# # Cálculo tempo total do script

# %%
t1 = time.time()
print("Script took {:.2} s".format(t1 - t0))
# Out:
# Script took 7e+03 s
